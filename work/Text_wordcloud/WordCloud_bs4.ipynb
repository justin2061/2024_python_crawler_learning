# %% [markdown]
# ## 安裝套件

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests) (2023.7.22)

# %%
# !pip install -q beautifulsoup4==4.11.1

# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 664.7 kB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=fe69ec57a1c0e16d4a6e2ffb11873fdeb1bce446e4b159c1d44152a832b89013
#   Stored in directory: /home/jovyan/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.11 sgmllib3k-1.0.0

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /opt/conda/lib/python3.11/site-packages (4.9.1)

# %%
# !pip install jieba
# Out:
# Collecting jieba
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 2.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: jieba
#   Building wheel for jieba (setup.py) ... done
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314458 sha256=4f7d0e06299f019aa43b0a03cef556673977ca235f1e69436eebe65596e3b709
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ac/60/cf/538a1f183409caf1fc136b5d2c2dee329001ef6da2c5084bef
# Successfully built jieba
# Installing collected packages: jieba
# Successfully installed jieba-0.42.1

# %%
# !mkdir jieba_data
# Out:
# mkdir: cannot create directory ‘jieba_data’: File exists

# %% [markdown]
# ### 下載字數較多的辭典檔

# %%
# !wget https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big -O jieba_data/dict.txt.big
# Out:
# --2024-07-12 21:01:18--  https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big [following]
# --2024-07-12 21:01:19--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [application/octet-stream]
# Saving to: ‘jieba_data/dict.txt.big’
#
# jieba_data/dict.txt 100%[===================>]   8.18M  1.55MB/s    in 5.4s
#
# 2024-07-12 21:01:26 (1.53 MB/s) - ‘jieba_data/dict.txt.big’ saved [8583143/8583143]

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.11/site-packages (from wordcloud) (2.0.0)
# Collecting pillow (from wordcloud)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting matplotlib (from wordcloud)
#   Downloading matplotlib-3.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->wordcloud)
#   Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->wordcloud)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->wordcloud)
#   Downloading fonttools-4.53.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib->wordcloud)
#   Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.2)
# Collecting pyparsing>=2.3.1 (from matplotlib->wordcloud)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (548 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.3/548.3 kB 1.9 MB/s eta 0:00:00a 0:00:01m
# Downloading matplotlib-3.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 1.8 MB/s eta 0:00:0000:0100:01
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 1.8 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 1.8 MB/s eta 0:00:0000:0100:01
# Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.8 MB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, wordcloud
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2 wordcloud-1.9.3

# %% [markdown]
# ## 解析 RSS

# %%
import feedparser

# %%
rss_url = "https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money"

# %%
newsFeed = feedparser.parse(rss_url)
newsFeed
# Out:
# {'bozo': False,
#  'entries': [{'title': '愛爾蘭第4屆翻譯擂台 黃璽台灣原民詩作為題',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '愛爾蘭第4屆翻譯擂台 黃璽台灣原民詩作為題'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8092251'}],
#    'link': 'https://money.udn.com/money/story/10511/8092251',
#    'published': 'Sat, 13 Jul 2024 02:03:15 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=18, tm_min=3, tm_sec=15, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '愛爾蘭三一大學與國立台灣文學館合作，近日啟動第4屆「翻譯擂台」競賽，廣邀各國好手將台灣原民詩人黃璽（TemuSuyan）...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '愛爾蘭三一大學與國立台灣文學館合作，近日啟動第4屆「翻譯擂台」競賽，廣邀各國好手將台灣原民詩人黃璽（TemuSuyan）...'},
#    'id': 'https://money.udn.com/money/story/10511/8092251',
#    'guidislink': False},
#   {'title': '拜登堅持不退選 路透社列出5點可能原因',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '拜登堅持不退選 路透社列出5點可能原因'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8092165'}],
#    'link': 'https://money.udn.com/money/story/10511/8092165',
#    'published': 'Fri, 12 Jul 2024 23:45:33 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=15, tm_min=45, tm_sec=33, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '美國總統拜登（Joe Biden）電視辯論表現慘不忍睹，一時之間勸退聲高漲。但為何現年81歲的拜登堅信，他會在11月5日...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國總統拜登（Joe Biden）電視辯論表現慘不忍睹，一時之間勸退聲高漲。但為何現年81歲的拜登堅信，他會在11月5日...'},
#    'id': 'https://money.udn.com/money/story/10511/8092165',
#    'guidislink': False},
#   {'title': '好萊塢換拜聲起 麥克道格拉斯：難以想像拜登做完第2任期',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '好萊塢換拜聲起 麥克道格拉斯：難以想像拜登做完第2任期'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8091957'}],
#    'link': 'https://money.udn.com/money/story/10511/8091957',
#    'published': 'Fri, 12 Jul 2024 22:45:51 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=14, tm_min=45, tm_sec=51, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '美國男星喬治克隆尼最近投書紐時呼籲總統拜登退選，開了好萊塢「換拜」第一槍。值此之際，奧斯卡影帝麥克道格拉斯也在受訪時表示...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國男星喬治克隆尼最近投書紐時呼籲總統拜登退選，開了好萊塢「換拜」第一槍。值此之際，奧斯卡影帝麥克道格拉斯也在受訪時表示...'},
#    'id': 'https://money.udn.com/money/story/10511/8091957',
#    'guidislink': False},
#   {'title': '終於現身 消息人士：前第一夫人梅蘭妮亞將參加共和黨全國代表大會',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '終於現身 消息人士：前第一夫人梅蘭妮亞將參加共和黨全國代表大會'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8091889'}],
#    'link': 'https://money.udn.com/money/story/10511/8091889',
#    'published': 'Fri, 12 Jul 2024 21:55:45 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=13, tm_min=55, tm_sec=45, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2024/07/12/realtime/29991750.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=4806&amp;sh=3204&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>一名熟悉共和黨全國代表大會的消息人士告訴美國NBC新聞，前第一夫人梅蘭妮亞將參加下周的共和黨全國代表大會。前總統川普積極...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2024/07/12/realtime/29991750.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=4806&amp;sh=3204&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>一名熟悉共和黨全國代表大會的消息人士告訴美國NBC新聞，前第一夫人梅蘭妮亞將參加下周的共和黨全國代表大會。前總統川普積極...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/8091889',
#    'guidislink': False},
#   {'title': '拜登永遠不會恢復過來！競選團隊內部人士：他的獲勝機會為「零」',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '拜登永遠不會恢復過來！競選團隊內部人士：他的獲勝機會為「零」'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8091739'}],
#    'link': 'https://money.udn.com/money/story/10511/8091739',
#    'published': 'Fri, 12 Jul 2024 19:50:37 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=11, tm_min=50, tm_sec=37, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2024/07/12/realtime/29991434.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國總統拜登11日晚間舉行記者會，捍衛自己的候選資格，但幾位最親密盟友卻在事前告訴NBC新聞，他們現在認為拜登獲勝機會為...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2024/07/12/realtime/29991434.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=1280&amp;sh=853&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國總統拜登11日晚間舉行記者會，捍衛自己的候選資格，但幾位最親密盟友卻在事前告訴NBC新聞，他們現在認為拜登獲勝機會為...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/8091739',
#    'guidislink': False},
#   {'title': '好萊塢富裕金主擔憂拜登年紀 揚言撤資逼他退選',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '好萊塢富裕金主擔憂拜登年紀 揚言撤資逼他退選'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8091519'}],
#    'link': 'https://money.udn.com/money/story/10511/8091519',
#    'published': 'Fri, 12 Jul 2024 17:54:35 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=9, tm_min=54, tm_sec=35, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '隨著美國總統大選逼近，若民主黨重要金主、好萊塢名人切斷贊助總統拜登的競選資金會如何？在巨星喬治克隆尼和其他富裕捐款者勸拜...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '隨著美國總統大選逼近，若民主黨重要金主、好萊塢名人切斷贊助總統拜登的競選資金會如何？在巨星喬治克隆尼和其他富裕捐款者勸拜...'},
#    'id': 'https://money.udn.com/money/story/10511/8091519',
#    'guidislink': False},
#   {'title': '才見完普亭 匈牙利總理北約峰會後又去見川普',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '才見完普亭 匈牙利總理北約峰會後又去見川普'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8091520'}],
#    'link': 'https://money.udn.com/money/story/10511/8091520',
#    'published': 'Fri, 12 Jul 2024 17:54:35 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=9, tm_min=54, tm_sec=35, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '匈牙利總理奧班結束於華府的北大西洋公約組織（NATO）峰會後，今天搭機轉赴佛羅里達州，會見前美國總統川普',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '匈牙利總理奧班結束於華府的北大西洋公約組織（NATO）峰會後，今天搭機轉赴佛羅里達州，會見前美國總統川普'},
#    'id': 'https://money.udn.com/money/story/10511/8091520',
#    'guidislink': False},
#   {'title': '川普陣營為拜登記者會點讚 不會導致他被迫退選、又提供新的攻擊材料',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '川普陣營為拜登記者會點讚 不會導致他被迫退選、又提供新的攻擊材料'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8091328'}],
#    'link': 'https://money.udn.com/money/story/10511/8091328',
#    'published': 'Fri, 12 Jul 2024 16:40:37 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=8, tm_min=40, tm_sec=37, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2024/07/12/realtime/29990205.jpg&amp;s=Y&amp;x=0&amp;y=9&amp;sw=1280&amp;sh=852&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國總統拜登11日晚間舉行個人記者會，強力捍衛自己勝任大位。對手川普的顧問和盟友則認為，拜登的表現對他們的選戰是最佳情況...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2024/07/12/realtime/29990205.jpg&amp;s=Y&amp;x=0&amp;y=9&amp;sw=1280&amp;sh=852&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國總統拜登11日晚間舉行個人記者會，強力捍衛自己勝任大位。對手川普的顧問和盟友則認為，拜登的表現對他們的選戰是最佳情況...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/8091328',
#    'guidislink': False},
#   {'title': 'CNN：歐巴馬與裴洛西曾私下憂心拜登選情',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': 'CNN：歐巴馬與裴洛西曾私下憂心拜登選情'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8091309'}],
#    'link': 'https://money.udn.com/money/story/10511/8091309',
#    'published': 'Fri, 12 Jul 2024 16:30:52 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=8, tm_min=30, tm_sec=52, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '美國有線電視新聞網（CNN）報導，美國前總統歐巴馬與前聯邦眾議院議長裴洛西私下談過現任總統拜登（Joe Biden）和他...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國有線電視新聞網（CNN）報導，美國前總統歐巴馬與前聯邦眾議院議長裴洛西私下談過現任總統拜登（Joe Biden）和他...'},
#    'id': 'https://money.udn.com/money/story/10511/8091309',
#    'guidislink': False},
#   {'title': '喬治克隆尼投書籲拜登退選 傳曾事先通知歐巴馬',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '喬治克隆尼投書籲拜登退選 傳曾事先通知歐巴馬'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8091040'}],
#    'link': 'https://money.udn.com/money/story/10511/8091040',
#    'published': 'Fri, 12 Jul 2024 14:30:51 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=6, tm_min=30, tm_sec=51, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '好萊塢巨星喬治克隆尼（George Clooney）昨天投書「紐約時報」公開呼籲美國總統拜登退選，據報他曾事先通知前總統...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '好萊塢巨星喬治克隆尼（George Clooney）昨天投書「紐約時報」公開呼籲美國總統拜登退選，據報他曾事先通知前總統...'},
#    'id': 'https://money.udn.com/money/story/10511/8091040',
#    'guidislink': False},
#   {'title': '拜登退選疑雲籠罩 北約3天峰會落幕誓挺烏克蘭',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '拜登退選疑雲籠罩 北約3天峰會落幕誓挺烏克蘭'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8090931'}],
#    'link': 'https://money.udn.com/money/story/10511/8090931',
#    'published': 'Fri, 12 Jul 2024 13:54:38 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=5, tm_min=54, tm_sec=38, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '北大西洋公約組織（NATO）今天在美國總統拜登是否適合競選連任的疑雲籠罩下結束3天峰會，北約各國領導人承諾持續支持烏克蘭...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '北大西洋公約組織（NATO）今天在美國總統拜登是否適合競選連任的疑雲籠罩下結束3天峰會，北約各國領導人承諾持續支持烏克蘭...'},
#    'id': 'https://money.udn.com/money/story/10511/8090931',
#    'guidislink': False},
#   {'title': '美消費支出最新警報：百事警告各所得族群顧客都在省錢',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美消費支出最新警報：百事警告各所得族群顧客都在省錢'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8090897'}],
#    'link': 'https://money.udn.com/money/story/10511/8090897',
#    'published': 'Fri, 12 Jul 2024 13:39:53 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=5, tm_min=39, tm_sec=53, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2024/07/12/realtime/29989013.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=3090&amp;sh=2060&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國包裝食品巨擘百事公司（Pepsi）與Conagra品牌公司上季業績疲弱，並表示美國購物者正面臨財務壓力，正成為美國消...</p>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '<p><img src="https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2024/07/12/realtime/29989013.jpg&amp;s=Y&amp;x=0&amp;y=0&amp;sw=3090&amp;sh=2060&amp;sl=W&amp;fw=180&amp;exp=3600" /><p>美國包裝食品巨擘百事公司（Pepsi）與Conagra品牌公司上季業績疲弱，並表示美國購物者正面臨財務壓力，正成為美國消...</p>'},
#    'id': 'https://money.udn.com/money/story/10511/8090897',
#    'guidislink': False},
#   {'title': '微軟投資阿聯AI公司 美議員憂敏感技術外流中國',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '微軟投資阿聯AI公司 美議員憂敏感技術外流中國'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8090628'}],
#    'link': 'https://money.udn.com/money/story/10511/8090628',
#    'published': 'Fri, 12 Jul 2024 12:00:46 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=4, tm_min=0, tm_sec=46, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '微軟公司日前宣布砸15億美元投資阿拉伯聯合大公國人工智慧（AI）公司G42，美國兩名共和黨籍國會議員要求總統拜登政府對此...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '微軟公司日前宣布砸15億美元投資阿拉伯聯合大公國人工智慧（AI）公司G42，美國兩名共和黨籍國會議員要求總統拜登政府對此...'},
#    'id': 'https://money.udn.com/money/story/10511/8090628',
#    'guidislink': False},
#   {'title': '拜登北約峰會再口誤 盟國紛解圍為他領導力背書',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '拜登北約峰會再口誤 盟國紛解圍為他領導力背書'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8090574'}],
#    'link': 'https://money.udn.com/money/story/10511/8090574',
#    'published': 'Fri, 12 Jul 2024 11:46:43 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=3, tm_min=46, tm_sec=43, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '美國總統拜登在北約峰會誤稱烏克蘭總統澤倫斯基為俄羅斯總統蒲亭，盟國領袖紛紛出言解圍並對拜登投下信任票。緩頰無論如何巧妙，...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國總統拜登在北約峰會誤稱烏克蘭總統澤倫斯基為俄羅斯總統蒲亭，盟國領袖紛紛出言解圍並對拜登投下信任票。緩頰無論如何巧妙，...'},
#    'id': 'https://money.udn.com/money/story/10511/8090574',
#    'guidislink': False},
#   {'title': '1小時記者會力搏勸退聲浪 拜登誓言選到底',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '1小時記者會力搏勸退聲浪 拜登誓言選到底'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8090535'}],
#    'link': 'https://money.udn.com/money/story/10511/8090535',
#    'published': 'Fri, 12 Jul 2024 11:30:46 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=3, tm_min=30, tm_sec=46, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '美國總統拜登因6月底的辯論表現差面臨「換拜」壓力。他今天透過一場近1小時的記者會及問答，展現對外交與政策的嫻熟掌控，強調...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國總統拜登因6月底的辯論表現差面臨「換拜」壓力。他今天透過一場近1小時的記者會及問答，展現對外交與政策的嫻熟掌控，強調...'},
#    'id': 'https://money.udn.com/money/story/10511/8090535',
#    'guidislink': False},
#   {'title': '拜登：沒有歐洲盟友要他退選  年紀能帶來智慧',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '拜登：沒有歐洲盟友要他退選  年紀能帶來智慧'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8090368'}],
#    'link': 'https://money.udn.com/money/story/10511/8090368',
#    'published': 'Fri, 12 Jul 2024 10:30:41 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=2, tm_min=30, tm_sec=41, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '美國總統拜登日前辯論表現差，要求他退選的聲浪延燒。拜登今天在北大西洋公約組織峰會後召開記者會說，沒有聽到歐洲領導人要他別...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國總統拜登日前辯論表現差，要求他退選的聲浪延燒。拜登今天在北大西洋公約組織峰會後召開記者會說，沒有聽到歐洲領導人要他別...'},
#    'id': 'https://money.udn.com/money/story/10511/8090368',
#    'guidislink': False},
#   {'title': '日月光擴矽谷第2廠區 攻美AI半導體測試供應鏈',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '日月光擴矽谷第2廠區 攻美AI半導體測試供應鏈'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8090337'}],
#    'link': 'https://money.udn.com/money/story/10511/8090337',
#    'published': 'Fri, 12 Jul 2024 10:21:19 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=2, tm_min=21, tm_sec=19, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '封測廠日月光投控旗下日月光半導體今天宣布，在美國加州聖荷西（SanJose）開設第2個美國廠區，擴大測試服務能力，佛利蒙...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '封測廠日月光投控旗下日月光半導體今天宣布，在美國加州聖荷西（SanJose）開設第2個美國廠區，擴大測試服務能力，佛利蒙...'},
#    'id': 'https://money.udn.com/money/story/10511/8090337',
#    'guidislink': False},
#   {'title': '拜登稱最有資格勝選 坦言其他人也可能擊敗川普',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '拜登稱最有資格勝選 坦言其他人也可能擊敗川普'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8090306'}],
#    'link': 'https://money.udn.com/money/story/10511/8090306',
#    'published': 'Fri, 12 Jul 2024 10:12:11 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=2, tm_min=12, tm_sec=11, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '美國總統拜登面臨黨內愈來愈多要求他退選的呼聲，他今天重申他認為自己是「最有資格」在11月總統大選對上川普的人，但坦言其他...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國總統拜登面臨黨內愈來愈多要求他退選的呼聲，他今天重申他認為自己是「最有資格」在11月總統大選對上川普的人，但坦言其他...'},
#    'id': 'https://money.udn.com/money/story/10511/8090306',
#    'guidislink': False},
#   {'title': '晚上8時後不工作要睡覺？拜登記者會被問到笑了',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '晚上8時後不工作要睡覺？拜登記者會被問到笑了'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8090292'}],
#    'link': 'https://money.udn.com/money/story/10511/8090292',
#    'published': 'Fri, 12 Jul 2024 10:06:12 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=2, tm_min=6, tm_sec=12, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '美國總統拜登今天在記者會上被問到近來有媒體報導他曾私下暗示，他的晚上活動時間要提早，因為必須在晚上8時上床睡覺，拜登回說...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '美國總統拜登今天在記者會上被問到近來有媒體報導他曾私下暗示，他的晚上活動時間要提早，因為必須在晚上8時上床睡覺，拜登回說...'},
#    'id': 'https://money.udn.com/money/story/10511/8090292',
#    'guidislink': False},
#   {'title': '才誤稱澤倫斯基為普亭 拜登又搞混賀錦麗與川普',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '才誤稱澤倫斯基為普亭 拜登又搞混賀錦麗與川普'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://money.udn.com/money/story/10511/8090137'}],
#    'link': 'https://money.udn.com/money/story/10511/8090137',
#    'published': 'Fri, 12 Jul 2024 09:00:12 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=1, tm_min=0, tm_sec=12, tm_wday=4, tm_yday=194, tm_isdst=0),
#    'summary': '81歲的美國總統拜登正努力平息各界對他年紀太大恐難以競選連任的疑慮，今天卻又在記者會上搞混副總統賀錦麗（Kamala H...',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#     'value': '81歲的美國總統拜登正努力平息各界對他年紀太大恐難以競選連任的疑慮，今天卻又在記者會上搞混副總統賀錦麗（Kamala H...'},
#    'id': 'https://money.udn.com/money/story/10511/8090137',
#    'guidislink': False}],
#  'feed': {'title': '經濟日報：不僅新聞速度 更有脈絡深度',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#    'value': '經濟日報：不僅新聞速度 更有脈絡深度'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://money.udn.com'}],
#   'link': 'https://money.udn.com',
#   'subtitle': '經濟日報每日提供除產業、股市、金融、國際、彭博及專欄等即時財經新聞，並針對重要議題製作去碎片、有脈絡的深度內容，提供解讀、分析、整理、精選專題、專家觀點等，幫助讀者擺脫資訊碎片化的困擾。',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#    'value': '經濟日報每日提供除產業、股市、金融、國際、彭博及專欄等即時財經新聞，並針對重要議題製作去碎片、有脈絡的深度內容，提供解讀、分析、整理、精選專題、專家觀點等，幫助讀者擺脫資訊碎片化的困擾。'},
#   'published': 'Sat, 13 Jul 2024 05:01:47 +0800',
#   'published_parsed': time.struct_time(tm_year=2024, tm_mon=7, tm_mday=12, tm_hour=21, tm_min=1, tm_sec=47, tm_wday=4, tm_yday=194, tm_isdst=0),
#   'rights': '聯合線上公司著作權所有@copy; udn.com. All Rights Reserved.',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#    'value': '聯合線上公司著作權所有@copy; udn.com. All Rights Reserved.'},
#   'language': 'zh-TW',
#   'ttl': '10'},
#  'headers': {'content-encoding': 'gzip',
#   'access-control-allow-credentials': 'true',
#   'alt-svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000',
#   'content-type': 'text/xml;charset=UTF-8',
#   'date': 'Fri, 12 Jul 2024 21:01:47 GMT',
#   'ec-r22-2-1': 'money',
#   'ec-version': 'All-Policy-20240528',
#   'server': 'nginx',
#   'service-worker-allowed': '/',
#   'via': '1.1 google',
#   'x-e': 'cl-mo-c3p7',
#   'x-mhn': 'money-ci3-5c4bd46dc9-rrw74',
#   'transfer-encoding': 'chunked',
#   'connection': 'close'},
#  'href': 'https://money.udn.com/rssfeed/news/1001/5588/10511?ch=money',
#  'status': 200,
#  'encoding': 'UTF-8',
#  'version': 'rss20',
#  'namespaces': {}}

# %% [markdown]
# ### 查看每個 entry 的 title, url

# %%
i = 1
for e in newsFeed['entries']:
    title = e['title']
    link_url = e['links'][0]['href']
    print("%s, %s, %s"%(i, title, link_url))
    i = i + 1
# Out:
# 1, 愛爾蘭第4屆翻譯擂台 黃璽台灣原民詩作為題, https://money.udn.com/money/story/10511/8092251
# 2, 拜登堅持不退選 路透社列出5點可能原因, https://money.udn.com/money/story/10511/8092165
# 3, 好萊塢換拜聲起 麥克道格拉斯：難以想像拜登做完第2任期, https://money.udn.com/money/story/10511/8091957
# 4, 終於現身 消息人士：前第一夫人梅蘭妮亞將參加共和黨全國代表大會, https://money.udn.com/money/story/10511/8091889
# 5, 拜登永遠不會恢復過來！競選團隊內部人士：他的獲勝機會為「零」, https://money.udn.com/money/story/10511/8091739
# 6, 好萊塢富裕金主擔憂拜登年紀 揚言撤資逼他退選, https://money.udn.com/money/story/10511/8091519
# 7, 才見完普亭 匈牙利總理北約峰會後又去見川普, https://money.udn.com/money/story/10511/8091520
# 8, 川普陣營為拜登記者會點讚 不會導致他被迫退選、又提供新的攻擊材料, https://money.udn.com/money/story/10511/8091328
# 9, CNN：歐巴馬與裴洛西曾私下憂心拜登選情, https://money.udn.com/money/story/10511/8091309
# 10, 喬治克隆尼投書籲拜登退選 傳曾事先通知歐巴馬, https://money.udn.com/money/story/10511/8091040
# 11, 拜登退選疑雲籠罩 北約3天峰會落幕誓挺烏克蘭, https://money.udn.com/money/story/10511/8090931
# 12, 美消費支出最新警報：百事警告各所得族群顧客都在省錢, https://money.udn.com/money/story/10511/8090897
# 13, 微軟投資阿聯AI公司 美議員憂敏感技術外流中國, https://money.udn.com/money/story/10511/8090628
# 14, 拜登北約峰會再口誤 盟國紛解圍為他領導力背書, https://money.udn.com/money/story/10511/8090574
# 15, 1小時記者會力搏勸退聲浪 拜登誓言選到底, https://money.udn.com/money/story/10511/8090535
# 16, 拜登：沒有歐洲盟友要他退選  年紀能帶來智慧, https://money.udn.com/money/story/10511/8090368
# 17, 日月光擴矽谷第2廠區 攻美AI半導體測試供應鏈, https://money.udn.com/money/story/10511/8090337
# 18, 拜登稱最有資格勝選 坦言其他人也可能擊敗川普, https://money.udn.com/money/story/10511/8090306
# 19, 晚上8時後不工作要睡覺？拜登記者會被問到笑了, https://money.udn.com/money/story/10511/8090292
# 20, 才誤稱澤倫斯基為普亭 拜登又搞混賀錦麗與川普, https://money.udn.com/money/story/10511/8090137

# %% [markdown]
# ### 解析html可以參考 https://lxml.de/lxmlhtml.html

# %% [markdown]
# ## 開始取得文章

# %% [markdown]
# ### 載入 library

# %%
import requests
from lxml import etree
from io import StringIO
import jieba
import pandas as pd
import time
import random
from bs4 import BeautifulSoup

# %% [markdown]
# ### 使用剛剛下載的辭典

# %%
#指定辭典檔
jieba.set_dictionary('jieba_data/dict.txt.big')

# %% [markdown]
# ### 設定 request header

# %%
#設定 request header
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36"
my_headers = {
    'User-Agent': user_agent,
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    "accept-encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
    "cache-control": "no-cache",
    "Accept-Charset": "UTF8,utf-8;q=0.7,*;q=0.7"
}

# %% [markdown]
# ### 先爬文

# %%
#分解動作

#爬文
each_article_text_list = []
for e in newsFeed['entries']:
    url = e['links'][0]['href']
    print(url)
    r = requests.get(url, headers = my_headers)
    if r.status_code == 200:
        soup = BeautifulSoup(r.text, 'html.parser')
        article_body = soup.find(id="article_body")
        if article_body:  # Check if the article_body element was found
            article_elements = article_body.find_all('p')
            for a_part in article_elements:
                if type(a_part.text) is str:
                    each_article_text_list.append(a_part.text.strip())
    sleep_time = random.randint(3, 10)
    print(f"sleep time: {sleep_time} sec")
    time.sleep(sleep_time)
    all_article_text = ''.join(each_article_text_list)
all_article_text
# Out:
# https://money.udn.com/money/story/10511/8092251
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/8092165
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/8091957
# sleep time: 10 sec
# https://money.udn.com/money/story/10511/8091889
# sleep time: 4 sec
# https://money.udn.com/money/story/10511/8091739
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/8091519
# sleep time: 4 sec
# https://money.udn.com/money/story/10511/8091520
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/8091328
# sleep time: 8 sec
# https://money.udn.com/money/story/10511/8091309
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/8091040
# sleep time: 9 sec
# https://money.udn.com/money/story/10511/8090931
# sleep time: 4 sec
# https://money.udn.com/money/story/10511/8090897
# sleep time: 7 sec
# https://money.udn.com/money/story/10511/8090628
# sleep time: 5 sec
# https://money.udn.com/money/story/10511/8090574
# sleep time: 5 sec
# https://money.udn.com/money/story/10511/8090535
# sleep time: 7 sec
# https://money.udn.com/money/story/10511/8090368
# sleep time: 6 sec
# https://money.udn.com/money/story/10511/8090337
# sleep time: 7 sec
# https://money.udn.com/money/story/10511/8090306
# sleep time: 3 sec
# https://money.udn.com/money/story/10511/8090292
# sleep time: 8 sec
# https://money.udn.com/money/story/10511/8090137
# sleep time: 5 sec
# '愛爾蘭三一大學與國立台灣文學館合作，近日啟動第4屆「翻譯擂台」競賽，廣邀各國好手將台灣原民詩人黃璽（TemuSuyan）的詩作「莎拉茅群訪談記事」譯為英語，投稿10月1日截止。生於1990年的黃璽具泰雅族與布農族血統，是台灣原住民新生代詩人，2021年以「莎拉茅群訪談記事」獲台灣文學獎「原住民漢語新詩創作」首獎，2023年出版詩集「骨鯁集」（Khu Ka Qaraw Qulih）。愛爾蘭都柏林三一大學（Trinity College Dublin）文學與文化翻譯中心（Centre for Literary & CulturalTranslation）2021年起與駐愛爾蘭代表處合作，舉辦翻譯擂台（Translation Slam），歷年陸續以台灣詩人的華語詩、台語詩及客語詩為題。競賽今年首次改由台灣文學館與愛爾蘭方合作舉辦，並以台灣原住民詩人的創作為題。黃璽的「莎拉茅群訪談記事」為華語詩。三一大學文學與文化翻譯中心主任哈德利（James Hadley）指出，「莎拉茅群訪談記事」雖是華語詩，卻深刻呈現台灣原民文化及原民社群面臨的挑戰。作品觸及水資源、過度開發、環境變遷等議題，愛爾蘭與台灣同為島國，可以同理體會。哈德利說，愛爾蘭高度重視文化多樣性；今年翻譯擂台以台灣原民詩作為題，既是愛爾蘭文壇創舉，也讓更多英語世界人士有機會瞭解豐富的台灣原民文化。為讓參賽者更容易親近作品，翻譯擂台特別錄製黃璽專訪及黃璽的詩作朗讀影音檔供參。駐愛爾蘭代表楊子葆表示，台文館4月曾在愛爾蘭舉辦「台灣原住民文學展」，接著翻譯擂台以台灣原民詩作為題，不僅讓愛爾蘭各界有機會進一步瞭解台灣歷史及其多樣文化，也促進台灣與愛爾蘭的交流對話。「莎拉茅群訪談記事」講述大甲溪流域泰雅族分支莎拉茅（Slamaw）群的歷史。翻譯擂台仿效美國詩人史密斯（Marc Smith）1984年在芝加哥舉辦的「尬詩擂台」（Poetry Slam），透過導入「競技」元素增進文學翻譯的趣味性。美國總統拜登（Joe Biden）電視辯論表現慘不忍睹，一時之間勸退聲高漲。但為何現年81歲的拜登堅信，他會在11月5日總統大選擊敗現年78歲的川普（Donald Trump）？路透社藉由訪談多位民主黨官員、幕僚、策士與金主，指出以下幾點原因：●拜登對自己深信不疑拜登儘管年事已高，但先前還是做出競選連任的決定。當時官員與他的政壇盟友告訴路透社，這主要是因為他相信自己是能擊敗川普的民主黨最佳人選。這些消息人士透露，拜登信不過副手賀錦麗（Kamala Harris）贏得中間選民的能力，尤其是在關鍵的搖擺州。此外，對於眾多等待上場的民主黨州長和很可能成為未來黨內領袖的國會議員，拜登也懷疑他們的能力。●拜登的人格特質懷抱堅持不懈的原則，向來是拜登度過充滿悲痛的人生與漫長從政生涯的關鍵。他說，這是源於父母的教誨。拜登表示，母親教導他：「人生某些時刻遭遇失敗是無可避免的，但放棄是不可原諒的。」然而，拜登的這項原則令諸多民主黨人擔憂。好萊塢男星喬治克隆尼（George Clooney）10日投書「紐約時報」（The New York Times）呼籲他退選時也呼應道：「與歲月對抗，是一場他不可能打贏的戰爭。我們沒有一個人能贏得了。」●拜登最親近幕僚比他本人還放不下數十年來，拜登讓自己身邊圍繞一群為數不多的資深幕僚作為幹部，例如政治顧問唐尼倫（MikeDonilon）、現任美國總統顧問（Counselor to thePresident）芮契提（Steve Ricchetti）及現任白宮副幕僚長利德（Bruce Reed）。這群人曾指導拜登度過先前幾次危機，這次也力勸他選到底。一名與白宮內仍有聯繫的拜登前幕僚表示：「我聽聞芮契提、利德和唐尼倫比拜登本人還堅持。他們已經（在白宮）生根，不想移動。」一位白宮官員證實這番說法，並稱拜登所有的高階幕僚都是這種心態。●一些民主黨人害怕賀錦麗帶來的變化路透社採訪了十幾位民主黨人，包括民選官員和活躍支持者，且當中不少是在兵家必爭的賓州。他們全都對於拜登的心智狀態和擊敗川普的能力深表擔憂。不過，對於若由賀錦麗帶頭組成的民主黨政府，他們同樣卻乏信任。●國會議員反對聲浪趨緩6月27日的電視辯論會過後不久，美國國會黑人國會議員連線（Congressional Black Caucus）和民主黨國會拉丁裔黨團（Congressional Hispanic Caucus）的領袖都發表支持拜登的聲明。這似乎使得批評聲浪趨緩。截至昨天，在民主黨掌握的213席聯邦眾議員和51席聯邦參議員當中，分別僅11人和1人懇請拜登急流勇退。美國男星喬治克隆尼最近投書紐時呼籲總統拜登退選，開了好萊塢「換拜」第一槍。值此之際，奧斯卡影帝麥克道格拉斯也在受訪時表示，他「難以想像」拜登能做完第2任期。喬治克隆尼（George Clooney）最近投書「紐約時報」（New York Times），發表長文要求拜登退選，並且語重心長指出，拜登11月總統大選贏不了，國會參眾兩院也會輸。英國「獨立報」（The Independent）報導，79歲的麥克道格拉斯（Michael Douglas）10日出席紐約舉行的電影紀錄片「燃燒的美國」（America’s Burning，暫譯）首映會時，也在紅毯上向外界表達他對拜登競選連任的擔憂。麥克道格拉斯告訴英國廣播公司（BBC），他難以想像拜登從現在起到4年半後的狀況，尤其在選戰如此激烈的時期，真得需要有人口條非常清楚。此外，麥克道格拉斯還表示，他對拜登在首場電視辯論的表現感到失望，因為他「無能」挑戰川普說的「所有謊話」。他還說，「各位已看到喬治克隆尼現今獲得關注…透過他的投書文章。也許這些有助促使優柔寡斷的政治人物前進」。在接受BBC訪問數小時前，麥克道格拉斯曾在美國廣播公司（ABC）晨間脫口秀「觀點」（The View）上指出，喬治克隆尼在紐時文章中提出「令人信服的觀點」。麥克道格拉斯還說，由於拜登在總統大選電視辯論表現欠佳，他對拜登的政治前景「感到極其擔憂」。一名熟悉共和黨全國代表大會的消息人士告訴美國NBC新聞，前第一夫人梅蘭妮亞將參加下周的共和黨全國代表大會。前總統川普積極爭取重返白宮之際，梅蘭妮亞缺席多場重要活動，包括此次大選在愛阿華州揭開序幕、川普「超級星期二」勝選派對等。不過，該名消息人士沒有立即回應梅蘭妮亞是否全程出席共和黨全國代表大會，及她會不會發表談話等問題。今年共和黨全國代表大會將在15日至18日於威斯康辛州密爾瓦基舉行。NBC新聞指出，梅蘭妮亞缺席多場川普的競選活動，也沒有參加川普在紐約的任何審判。她先前最後一次和丈夫川普一起出席公共活動是在3月19日，當時他們都去佛州初選投票。她在川普競選期間參加了一些私人籌款活動，美國前總統川普（左）和前第一夫人梅蘭妮亞（右）。美聯社美國總統拜登11日晚間舉行記者會，捍衛自己的候選資格，但幾位最親密盟友卻在事前告訴NBC新聞，他們現在認為拜登獲勝機會為零，而且帶衰同黨籍候選人的可能性越來越高。報導稱，這幾位拜登盟友包括3位直接參與選戰的人士，全都要求匿名；一位競選陣團隊幹部說，「他需要退選」，並稱「他永遠不會從這件事恢復過來」。拜登在6月27日的首場辯論會以潰敗收場，過去2周一直在努力穩定競選活動，正在進行的整頓行動包括11日當天的高級幕僚私下會晤同黨參議員及當晚的記者會，想要讓民代和黨內幹部放心，但不僅收效甚微，反而發生了相反的結果。據報導，認為拜登應該重新考慮決定繼續競選的民主黨人士，已經增加到包括負責引導競選團隊獲勝的幕僚、黨工和幹部。接受NBC新聞採訪的人士表示，即使在競選團隊成員跟支援的民主黨外圍團體內部，拜登應該退選，並把民主黨提名留給其他人（最有可能是副總統賀錦麗）的情緒也十分普遍。另一位努力讓他選上的人士說，「參與選戰的人中，沒人認為他有出路」。第3名接近競選連任團隊的人士表示，像是圍繞著拜登認知能力的問題，缺乏募款活動，更多民調顯示拜登的支持度下降，而其他候選人表示更好，都讓目前的情勢難以為繼。該人士還說，他們不知道競選團隊如何取勝。另外2位跟拜登關係密切的人士告訴NBC新聞，儘管他們還沒放棄好轉的所有希望，卻視此為越來越不可能的結果。他們認為，11月擊敗川普的目標應該凌駕於支持拜登。一位致力讓拜登選上的人士說，「對我，還有我們很多人來說，問題在誰是打敗川普的最佳人選？我們有很多人是死忠的民主黨支持者，正在質疑我們對這一點的最初想法。」拜登競選團隊發言人達克洛（TJ Ducklo）表示，NBC新聞掌握的內幕消息「明顯是假的，這個團隊跟總統站在一起」。但報導指出，對於是否繼續競選，決定最終落在拜登身上，而他一直堅稱自己「哪裡都不會去」。然而，這些消息人士表示，無論是在11月之前退選，或是在投票日輸給川普，拜登已經完了。推特/X連結：https://x.com/natashakorecki/status/1811436556294443139美國總統拜登在北約華府峰會最後一天的11日舉行記者會。美聯社隨著美國總統大選逼近，若民主黨重要金主、好萊塢名人切斷贊助總統拜登的競選資金會如何？在巨星喬治克隆尼和其他富裕捐款者勸拜登退選後，這些金主撤資的可能性已升高。法新社報導，喬治克隆尼（George Clooney）10日投書「紐約時報」（The New York Times）說，「我對拜登（Joe Biden）青眼有加，但我們需要重新找一位總統參選人」。拜登之前與共和黨對手川普（Donald Trump）進行總統大選電視辯論，表現慘不忍睹，再度引發外界擔心81歲的拜登是否適合爭取連任。喬治克隆尼的聲明已對拜登造成重大打擊。就在3週前， ...

# %% [markdown]
# ### 做分詞

# %%
#分詞
seg_words_list = jieba.lcut(all_article_text)
seg_words_list
# Out:
# Building prefix dict from /home/jovyan/work/Text_wordcloud/jieba_data/dict.txt.big ...
# Dumping model to file cache /tmp/jieba.u240ff8c1e70462be159af457c3f6d652.cache
# Loading model cost 4.049 seconds.
# Prefix dict has been built successfully.
# ['愛爾蘭',
#  '三一',
#  '大學',
#  '與',
#  '國立',
#  '台灣',
#  '文學館',
#  '合作',
#  '，',
#  '近日',
#  '啟動',
#  '第',
#  '4',
#  '屆',
#  '「',
#  '翻譯',
#  '擂台',
#  '」',
#  '競賽',
#  '，',
#  '廣邀',
#  '各國',
#  '好手',
#  '將台灣',
#  '原民',
#  '詩人',
#  '黃',
#  '璽',
#  '（',
#  'TemuSuyan',
#  '）',
#  '的',
#  '詩作',
#  '「',
#  '莎拉',
#  '茅群',
#  '訪談',
#  '記事',
#  '」',
#  '譯為',
#  '英語',
#  '，',
#  '投稿',
#  '10',
#  '月',
#  '1',
#  '日',
#  '截止',
#  '。',
#  '生於',
#  '1990',
#  '年',
#  '的',
#  '黃',
#  '璽',
#  '具',
#  '泰雅族',
#  '與',
#  '布農族',
#  '血統',
#  '，',
#  '是',
#  '台灣',
#  '原住民',
#  '新生代',
#  '詩人',
#  '，',
#  '2021',
#  '年',
#  '以',
#  '「',
#  '莎拉',
#  '茅群',
#  '訪談',
#  '記事',
#  '」',
#  '獲台灣',
#  '文學獎',
#  '「',
#  '原住民',
#  '漢語',
#  '新詩',
#  '創作',
#  '」',
#  '首獎',
#  '，',
#  '2023',
#  '年',
#  '出版',
#  '詩集',
#  '「',
#  '骨鯁',
#  '集',
#  '」',
#  '（',
#  'Khu',
#  ' ',
#  'Ka',
#  ' ',
#  'Qaraw',
#  ' ',
#  'Qulih',
#  '）',
#  '。',
#  '愛爾蘭',
#  '都柏林',
#  '三一',
#  '大學',
#  '（',
#  'Trinity',
#  ' ',
#  'College',
#  ' ',
#  'Dublin',
#  '）',
#  '文學',
#  '與',
#  '文化',
#  '翻譯',
#  '中心',
#  '（',
#  'Centre',
#  ' ',
#  'for',
#  ' ',
#  'Literary',
#  ' ',
#  '&',
#  ' ',
#  'CulturalTranslation',
#  '）',
#  '2021',
#  '年',
#  '起',
#  '與',
#  '駐',
#  '愛爾蘭',
#  '代表處',
#  '合作',
#  '，',
#  '舉辦',
#  '翻譯',
#  '擂台',
#  '（',
#  'Translation',
#  ' ',
#  'Slam',
#  '）',
#  '，',
#  '歷年',
#  '陸續',
#  '以台灣',
#  '詩人',
#  '的',
#  '華語',
#  '詩',
#  '、',
#  '台語',
#  '詩及',
#  '客語',
#  '詩為題',
#  '。',
#  '競賽',
#  '今年',
#  '首次',
#  '改由',
#  '台灣',
#  '文學館',
#  '與',
#  '愛爾蘭',
#  '方',
#  '合作',
#  '舉辦',
#  '，',
#  '並以',
#  '台灣',
#  '原住民',
#  '詩人',
#  '的',
#  '創作',
#  '為題',
#  '。',
#  '黃',
#  '璽',
#  '的',
#  '「',
#  '莎拉',
#  '茅群',
#  '訪談',
#  '記事',
#  '」',
#  '為',
#  '華語',
#  '詩',
#  '。',
#  '三一',
#  '大學',
#  '文學',
#  '與',
#  '文化',
#  '翻譯',
#  '中心',
#  '主任',
#  '哈德',
#  '利',
#  '（',
#  'James',
#  ' ',
#  'Hadley',
#  '）',
#  '指出',
#  '，',
#  '「',
#  '莎拉',
#  '茅群',
#  '訪談',
#  '記事',
#  '」',
#  '雖',
#  '是',
#  '華語',
#  '詩',
#  '，',
#  '卻',
#  '深刻',
#  '呈現',
#  '台灣',
#  '原民',
#  '文化',
#  '及',
#  '原民',
#  '社群',
#  '面臨',
#  '的',
#  '挑戰',
#  '。',
#  '作品',
#  '觸及',
#  '水資源',
#  '、',
#  '過度',
#  '開發',
#  '、',
#  '環境',
#  '變遷',
#  '等',
#  '議題',
#  '，',
#  '愛爾蘭',
#  '與',
#  '台灣',
#  '同為',
#  '島國',
#  '，',
#  '可以',
#  '同理',
#  '體會',
#  '。',
#  '哈德',
#  '利說',
#  '，',
#  '愛爾蘭',
#  '高度重視',
#  '文化',
#  '多樣性',
#  '；',
#  '今年',
#  '翻譯',
#  '擂台',
#  '以台灣',
#  '原民',
#  '詩作',
#  '為題',
#  '，',
#  '既',
#  '是',
#  '愛爾蘭',
#  '文壇',
#  '創舉',
#  '，',
#  '也',
#  '讓',
#  '更',
#  '多',
#  '英語',
#  '世界',
#  '人士',
#  '有',
#  '機會',
#  '瞭解',
#  '豐富',
#  '的',
#  '台灣',
#  '原民',
#  '文化',
#  '。',
#  '為',
#  '讓',
#  '參賽者',
#  '更',
#  '容易',
#  '親近',
#  '作品',
#  '，',
#  '翻譯',
#  '擂台',
#  '特別',
#  '錄製',
#  '黃',
#  '璽',
#  '專訪',
#  '及黃璽',
#  '的',
#  '詩作',
#  '朗讀',
#  '影音',
#  '檔供',
#  '參',
#  '。',
#  '駐',
#  '愛爾蘭',
#  '代表',
#  '楊子',
#  '葆',
#  '表示',
#  '，',
#  '台文館',
#  '4',
#  '月',
#  '曾',
#  '在',
#  '愛爾蘭',
#  '舉辦',
#  '「',
#  '台灣',
#  '原住民',
#  '文學',
#  '展',
#  '」',
#  '，',
#  '接著',
#  '翻譯',
#  '擂台',
#  '以台灣',
#  '原民',
#  '詩作',
#  '為題',
#  '，',
#  '不僅',
#  '讓',
#  '愛爾蘭',
#  '各界',
#  '有',
#  '機會',
#  '進一步',
#  '瞭解',
#  '台灣',
#  '歷史',
#  '及其',
#  '多樣',
#  '文化',
#  '，',
#  '也',
#  '促進',
#  '台灣',
#  '與',
#  '愛爾蘭',
#  '的',
#  '交流',
#  '對話',
#  '。',
#  '「',
#  '莎拉',
#  '茅群',
#  '訪談',
#  '記事',
#  '」',
#  '講述',
#  '大甲溪',
#  '流域',
#  '泰雅族',
#  '分支',
#  '莎拉',
#  '茅',
#  '（',
#  'Slamaw',
#  '）',
#  '群',
#  '的',
#  '歷史',
#  '。',
#  '翻譯',
#  '擂台',
#  '仿效',
#  '美國',
#  '詩人',
#  '史密斯',
#  '（',
#  'Marc',
#  ' ',
#  'Smith',
#  '）',
#  '1984',
#  '年',
#  '在',
#  '芝加哥',
#  '舉辦',
#  '的',
#  '「',
#  '尬',
#  '詩',
#  '擂台',
#  '」',
#  '（',
#  'Poetry',
#  ' ',
#  'Slam',
#  '）',
#  '，',
#  '透過',
#  '導入',
#  '「',
#  '競技',
#  '」',
#  '元素',
#  '增進',
#  '文學',
#  '翻譯',
#  '的',
#  '趣味性',
#  '。',
#  '美國',
#  '總統',
#  '拜登',
#  '（',
#  'Joe',
#  ' ',
#  'Biden',
#  '）',
#  '電視辯論',
#  '表現',
#  '慘不忍睹',
#  '，',
#  '一時之間',
#  '勸退',
#  '聲',
#  '高漲',
#  '。',
#  '但',
#  '為何',
#  '現年',
#  '81',
#  '歲',
#  '的',
#  '拜登',
#  '堅信',
#  '，',
#  '他會',
#  '在',
#  '11',
#  '月',
#  '5',
#  '日',
#  '總統大選',
#  '擊敗',
#  '現年',
#  '78',
#  '歲',
#  '的',
#  '川普',
#  '（',
#  'Donald',
#  ' ',
#  'Trump',
#  '）',
#  '？',
#  '路透社',
#  '藉由',
#  '訪談',
#  '多位',
#  '民主黨',
#  '官員',
#  '、',
#  '幕僚',
#  '、',
#  '策士',
#  '與',
#  '金主',
#  '，',
#  '指出',
#  '以下幾點',
#  '原因',
#  '：',
#  '●',
#  '拜登',
#  '對',
#  '自己',
#  '深信不疑',
#  '拜登',
#  '儘管',
#  '年事已高',
#  '，',
#  '但',
#  '先前',
#  '還是',
#  '做出',
#  '競選',
#  '連任',
#  '的',
#  '決定',
#  '。',
#  '當時',
#  '官員',
#  '與',
#  '他',
#  '的',
#  '政壇',
#  '盟友',
#  '告訴',
#  '路透社',
#  '，',
#  '這',
#  '主要',
#  '是',
#  '因為',
#  '他',
#  '相信',
#  '自己',
#  '是',
#  '能',
#  '擊敗',
#  '川普',
#  '的',
#  '民主黨',
#  '最佳人選',
#  '。',
#  '這些',
#  '消息人士',
#  '透露',
#  '，',
#  '拜登',
#  '信不過',
#  '副手',
#  '賀錦麗',
#  '（',
#  'Kamala',
#  ' ',
#  'Harris',
#  '）',
#  '贏得',
#  '中間',
#  '選民',
#  '的',
#  '能力',
#  '，',
#  '尤其',
#  '是',
#  '在',
#  '關鍵',
#  '的',
#  '搖擺',
#  '州',
#  '。',
#  '此外',
#  '，',
#  '對於',
#  '眾多',
#  '等待',
#  '上場',
#  '的',
#  '民主黨',
#  '州長',
#  '和',
#  '很',
#  '可能',
#  '成為',
#  '未來',
#  '黨內',
#  '領袖',
#  '的',
#  '國會議員',
#  '，',
#  '拜登',
#  '也',
#  '懷疑',
#  '他們',
#  '的',
#  '能力',
#  '。',
#  '●',
#  '拜登',
#  '的',
#  '人格特質',
#  '懷抱',
#  '堅持不懈',
#  '的',
#  '原則',
#  '，',
#  '向來',
#  '是',
#  '拜登',
#  '度過',
#  '充滿',
#  '悲痛',
#  '的',
#  '人生',
#  '與',
#  '漫長',
#  '從政',
#  '生涯',
#  '的',
#  '關鍵',
#  '。',
#  '他',
#  '說',
#  '，',
#  '這是',
#  '源於',
#  '父母',
#  '的',
#  '教誨',
#  '。',
#  '拜登',
#  '表示',
#  '，',
#  '母親',
#  '教導',
#  '他',
#  '：',
#  '「',
#  '人生',
#  '某些',
#  '時刻',
#  '遭遇',
#  '失敗',
#  '是',
#  '無可避免',
#  '的',
#  '，',
#  '但',
#  '放棄',
#  '是',
#  '不可',
#  '原諒',
#  '的',
#  '。',
#  '」',
#  '然而',
#  '，',
#  '拜登',
#  '的',
#  '這項',
#  '原則',
#  '令',
#  '諸多',
#  '民主黨人',
#  '擔憂',
#  '。',
#  '好萊塢',
#  '男星',
#  '喬治',
#  '克隆',
#  '尼',
#  '（',
#  'George',
#  ' ',
#  'Clooney',
#  '）',
#  '10',
#  '日',
#  '投書',
#  '「',
#  '紐約時報',
#  '」',
#  '（',
#  'The',
#  ' ',
#  'New',
#  ' ',
#  'York',
#  ' ',
#  'Times',
#  '）',
#  '呼籲',
#  '他',
#  '退選',
#  '時',
#  '也',
#  '呼應',
#  '道',
#  '：',
#  '「',
#  '與',
#  '歲月',
#  '對抗',
#  '，',
#  '是',
#  '一場',
#  '他',
#  '不',
#  '可能',
#  '打贏',
#  '的',
#  '戰爭',
#  '。',
#  '我們',
#  '沒有',
#  '一個',
#  '人能',
#  '贏得',
#  '了',
#  '。',
#  '」',
#  '●',
#  '拜登',
#  '最',
#  '親近',
#  '幕僚',
#  '比',
#  '他',
#  '本人',
#  '還',
#  '放不下',
#  '數十年',
#  '來',
#  '，',
#  '拜登',
#  '讓',
#  '自己',
#  '身邊',
#  '圍繞',
#  '一群',
#  '為數',
#  '不',
#  '多',
#  '的',
#  '資深',
#  '幕僚',
#  '作為',
#  '幹部',
#  '，',
#  '例如',
#  '政治',
#  '顧問',
#  '唐尼倫',
#  '（',
#  'MikeDonilon',
#  '）',
#  '、',
#  '現任',
#  '美國',
#  '總統',
#  '顧問',
#  '（',
#  'Counselor',
#  ' ',
#  'to',
#  ' ',
#  'thePresident',
#  '）',
#  '芮契提',
#  '（',
#  'Steve',
#  ' ',
#  'Ricchetti',
#  '）',
#  '及',
#  '現任',
#  '白宮',
#  '副',
#  '幕僚長',
#  '利德',
#  '（',
#  'Bruce',
#  ' ',
#  'Reed',
#  '）',
#  '。',
#  '這群',
#  '人',
#  '曾',
#  '指導',
#  '拜登',
#  '度過',
#  '先前',
#  '幾次',
#  '危機',
#  '，',
#  '這次',
#  '也',
#  '力勸',
#  '他選',
#  '到底',
#  '。',
#  '一名',
#  '與',
#  '白宮',
#  '內',
#  '仍',
#  '有',
#  '聯繫',
#  '的',
#  '拜登',
#  '前',
#  '幕僚',
#  '表示',
#  '：',
#  '「',
#  '我',
#  '聽聞',
#  '芮契提',
#  '、',
#  '利德',
#  '和',
#  '唐尼',
#  '倫比',
#  '拜登',
#  '本人',
#  '還',
#  '堅持',
#  '。',
#  '他們',
#  '已經',
#  '（',
#  '在',
#  '白宮',
#  '）',
#  '生根',
#  '，',
#  '不想',
#  '移動',
#  '。',
#  '」',
#  '一位',
#  '白宮',
#  '官員',
#  '證實',
#  '這番',
#  '說法',
#  '，',
#  '並稱',
#  '拜登',
#  '所有',
#  '的',
#  '高階',
#  '幕僚',
#  '都',
#  '是',
#  '這種',
#  '心態',
#  '。',
#  '●',
#  '一些',
#  '民主黨人',
#  '害怕',
#  '賀錦麗',
#  '帶來',
#  '的',
#  '變化',
#  '路透社',
#  '採訪',
#  '了',
#  '十幾位',
#  '民主黨人',
#  '，',
#  '包括',
#  '民選',
#  '官員',
#  '和',
#  '活躍',
#  '支持者',
#  '，',
#  '且',
#  '當中',
#  '不少',
#  '是',
#  '在',
#  '兵家必爭',
#  '的',
#  '賓州',
#  '。',
#  '他們',
#  '全都',
#  '對於',
#  '拜登',
#  '的',
#  '心智',
#  '狀態',
#  '和',
#  '擊敗',
#  '川普',
#  '的',
#  '能力',
#  '深表',
#  '擔憂',
#  '。',
#  '不過',
#  '，',
#  '對於',
#  '若',
#  '由',
#  '賀錦麗',
#  '帶頭',
#  '組成',
#  '的',
#  '民主黨',
#  '政府',
#  '，',
#  '他們',
#  '同樣',
#  '卻乏',
#  '信任',
#  '。',
#  '●',
#  '國會議員',
#  '反對',
#  '聲浪',
#  '趨緩',
#  '6',
#  '月',
#  '27',
#  '日',
#  '的',
#  '電視辯論',
#  '會',
#  '過後',
#  '不久',
#  '，',
#  '美國國會',
#  '黑人',
#  '國會議員',
#  '連線',
#  '（',
#  'Congressional',
#  ' ',
#  'Black',
#  ' ',
#  'Caucus',
#  '）',
#  '和',
#  '民主黨',
#  '國會',
#  '拉丁',
#  '裔',
#  '黨團',
#  '（',
#  'Congressional',
#  ' ',
#  'Hispanic',
#  ' ',
#  'Caucus',
#  '）',
#  '的',
#  '領袖',
#  '都',
#  '發表',
#  '支持',
#  '拜登',
#  '的',
#  '聲明',
#  '。',
#  '這',
#  '似乎',
#  '使得',
#  '批評',
#  '聲浪',
#  '趨緩',
#  '。',
#  '截至',
#  '昨天',
#  '，',
#  '在',
#  '民主黨',
#  '掌握',
#  '的',
#  '213',
#  '席',
#  '聯邦',
#  '眾',
#  '議員',
#  '和',
#  '51',
#  '席',
#  '聯邦',
#  '參議員',
#  '當中',
#  '，',
#  '分別',
#  '僅',
#  '11',
#  '人',
#  '和',
#  '1',
#  '人',
#  '懇請',
#  '拜登',
#  '急流勇退',
#  '。',
#  '美國',
#  '男星',
#  ...]

# %%
# !ls jieba_data
# Out:
# dict.txt.big  dict.txt.small  mydict.txt  stop_words.txt

# %% [markdown]
# ### 準備 stop word

# %%
#stop word
with open(file='jieba_data/stop_words.txt', mode='r', encoding='utf-8') as file:
    stop_words = file.read().split('\n')
stop_words
# Out:
# ['the',
#  'of',
#  'is',
#  'and',
#  'to',
#  'in',
#  'that',
#  'we',
#  'for',
#  'an',
#  'are',
#  'by',
#  'be',
#  'as',
#  'on',
#  'with',
#  'can',
#  'if',
#  'from',
#  'which',
#  'you',
#  'it',
#  'this',
#  'then',
#  'at',
#  'have',
#  'all',
#  'not',
#  'one',
#  'has',
#  'or',
#  'that',
#  '的',
#  '了',
#  '和',
#  '是',
#  '就',
#  '都',
#  '而',
#  '及',
#  '與',
#  '著',
#  '或',
#  '一個',
#  '沒有',
#  '我們',
#  '你們',
#  '妳們',
#  '他們',
#  '她們',
#  '是否']

# %% [markdown]
# ### 準備一個利用stop word過濾後的分詞結果

# %%
#分詞
seg_stop_words_list = []
seg_words_list = jieba.lcut(all_article_text)
for term in seg_words_list:
    if term not in stop_words:
        seg_stop_words_list.append(term)
seg_stop_words_list
# Out:
# ['愛爾蘭',
#  '三一',
#  '大學',
#  '國立',
#  '台灣',
#  '文學館',
#  '合作',
#  '，',
#  '近日',
#  '啟動',
#  '第',
#  '4',
#  '屆',
#  '「',
#  '翻譯',
#  '擂台',
#  '」',
#  '競賽',
#  '，',
#  '廣邀',
#  '各國',
#  '好手',
#  '將台灣',
#  '原民',
#  '詩人',
#  '黃',
#  '璽',
#  '（',
#  'TemuSuyan',
#  '）',
#  '詩作',
#  '「',
#  '莎拉',
#  '茅群',
#  '訪談',
#  '記事',
#  '」',
#  '譯為',
#  '英語',
#  '，',
#  '投稿',
#  '10',
#  '月',
#  '1',
#  '日',
#  '截止',
#  '。',
#  '生於',
#  '1990',
#  '年',
#  '黃',
#  '璽',
#  '具',
#  '泰雅族',
#  '布農族',
#  '血統',
#  '，',
#  '台灣',
#  '原住民',
#  '新生代',
#  '詩人',
#  '，',
#  '2021',
#  '年',
#  '以',
#  '「',
#  '莎拉',
#  '茅群',
#  '訪談',
#  '記事',
#  '」',
#  '獲台灣',
#  '文學獎',
#  '「',
#  '原住民',
#  '漢語',
#  '新詩',
#  '創作',
#  '」',
#  '首獎',
#  '，',
#  '2023',
#  '年',
#  '出版',
#  '詩集',
#  '「',
#  '骨鯁',
#  '集',
#  '」',
#  '（',
#  'Khu',
#  ' ',
#  'Ka',
#  ' ',
#  'Qaraw',
#  ' ',
#  'Qulih',
#  '）',
#  '。',
#  '愛爾蘭',
#  '都柏林',
#  '三一',
#  '大學',
#  '（',
#  'Trinity',
#  ' ',
#  'College',
#  ' ',
#  'Dublin',
#  '）',
#  '文學',
#  '文化',
#  '翻譯',
#  '中心',
#  '（',
#  'Centre',
#  ' ',
#  ' ',
#  'Literary',
#  ' ',
#  '&',
#  ' ',
#  'CulturalTranslation',
#  '）',
#  '2021',
#  '年',
#  '起',
#  '駐',
#  '愛爾蘭',
#  '代表處',
#  '合作',
#  '，',
#  '舉辦',
#  '翻譯',
#  '擂台',
#  '（',
#  'Translation',
#  ' ',
#  'Slam',
#  '）',
#  '，',
#  '歷年',
#  '陸續',
#  '以台灣',
#  '詩人',
#  '華語',
#  '詩',
#  '、',
#  '台語',
#  '詩及',
#  '客語',
#  '詩為題',
#  '。',
#  '競賽',
#  '今年',
#  '首次',
#  '改由',
#  '台灣',
#  '文學館',
#  '愛爾蘭',
#  '方',
#  '合作',
#  '舉辦',
#  '，',
#  '並以',
#  '台灣',
#  '原住民',
#  '詩人',
#  '創作',
#  '為題',
#  '。',
#  '黃',
#  '璽',
#  '「',
#  '莎拉',
#  '茅群',
#  '訪談',
#  '記事',
#  '」',
#  '為',
#  '華語',
#  '詩',
#  '。',
#  '三一',
#  '大學',
#  '文學',
#  '文化',
#  '翻譯',
#  '中心',
#  '主任',
#  '哈德',
#  '利',
#  '（',
#  'James',
#  ' ',
#  'Hadley',
#  '）',
#  '指出',
#  '，',
#  '「',
#  '莎拉',
#  '茅群',
#  '訪談',
#  '記事',
#  '」',
#  '雖',
#  '華語',
#  '詩',
#  '，',
#  '卻',
#  '深刻',
#  '呈現',
#  '台灣',
#  '原民',
#  '文化',
#  '原民',
#  '社群',
#  '面臨',
#  '挑戰',
#  '。',
#  '作品',
#  '觸及',
#  '水資源',
#  '、',
#  '過度',
#  '開發',
#  '、',
#  '環境',
#  '變遷',
#  '等',
#  '議題',
#  '，',
#  '愛爾蘭',
#  '台灣',
#  '同為',
#  '島國',
#  '，',
#  '可以',
#  '同理',
#  '體會',
#  '。',
#  '哈德',
#  '利說',
#  '，',
#  '愛爾蘭',
#  '高度重視',
#  '文化',
#  '多樣性',
#  '；',
#  '今年',
#  '翻譯',
#  '擂台',
#  '以台灣',
#  '原民',
#  '詩作',
#  '為題',
#  '，',
#  '既',
#  '愛爾蘭',
#  '文壇',
#  '創舉',
#  '，',
#  '也',
#  '讓',
#  '更',
#  '多',
#  '英語',
#  '世界',
#  '人士',
#  '有',
#  '機會',
#  '瞭解',
#  '豐富',
#  '台灣',
#  '原民',
#  '文化',
#  '。',
#  '為',
#  '讓',
#  '參賽者',
#  '更',
#  '容易',
#  '親近',
#  '作品',
#  '，',
#  '翻譯',
#  '擂台',
#  '特別',
#  '錄製',
#  '黃',
#  '璽',
#  '專訪',
#  '及黃璽',
#  '詩作',
#  '朗讀',
#  '影音',
#  '檔供',
#  '參',
#  '。',
#  '駐',
#  '愛爾蘭',
#  '代表',
#  '楊子',
#  '葆',
#  '表示',
#  '，',
#  '台文館',
#  '4',
#  '月',
#  '曾',
#  '在',
#  '愛爾蘭',
#  '舉辦',
#  '「',
#  '台灣',
#  '原住民',
#  '文學',
#  '展',
#  '」',
#  '，',
#  '接著',
#  '翻譯',
#  '擂台',
#  '以台灣',
#  '原民',
#  '詩作',
#  '為題',
#  '，',
#  '不僅',
#  '讓',
#  '愛爾蘭',
#  '各界',
#  '有',
#  '機會',
#  '進一步',
#  '瞭解',
#  '台灣',
#  '歷史',
#  '及其',
#  '多樣',
#  '文化',
#  '，',
#  '也',
#  '促進',
#  '台灣',
#  '愛爾蘭',
#  '交流',
#  '對話',
#  '。',
#  '「',
#  '莎拉',
#  '茅群',
#  '訪談',
#  '記事',
#  '」',
#  '講述',
#  '大甲溪',
#  '流域',
#  '泰雅族',
#  '分支',
#  '莎拉',
#  '茅',
#  '（',
#  'Slamaw',
#  '）',
#  '群',
#  '歷史',
#  '。',
#  '翻譯',
#  '擂台',
#  '仿效',
#  '美國',
#  '詩人',
#  '史密斯',
#  '（',
#  'Marc',
#  ' ',
#  'Smith',
#  '）',
#  '1984',
#  '年',
#  '在',
#  '芝加哥',
#  '舉辦',
#  '「',
#  '尬',
#  '詩',
#  '擂台',
#  '」',
#  '（',
#  'Poetry',
#  ' ',
#  'Slam',
#  '）',
#  '，',
#  '透過',
#  '導入',
#  '「',
#  '競技',
#  '」',
#  '元素',
#  '增進',
#  '文學',
#  '翻譯',
#  '趣味性',
#  '。',
#  '美國',
#  '總統',
#  '拜登',
#  '（',
#  'Joe',
#  ' ',
#  'Biden',
#  '）',
#  '電視辯論',
#  '表現',
#  '慘不忍睹',
#  '，',
#  '一時之間',
#  '勸退',
#  '聲',
#  '高漲',
#  '。',
#  '但',
#  '為何',
#  '現年',
#  '81',
#  '歲',
#  '拜登',
#  '堅信',
#  '，',
#  '他會',
#  '在',
#  '11',
#  '月',
#  '5',
#  '日',
#  '總統大選',
#  '擊敗',
#  '現年',
#  '78',
#  '歲',
#  '川普',
#  '（',
#  'Donald',
#  ' ',
#  'Trump',
#  '）',
#  '？',
#  '路透社',
#  '藉由',
#  '訪談',
#  '多位',
#  '民主黨',
#  '官員',
#  '、',
#  '幕僚',
#  '、',
#  '策士',
#  '金主',
#  '，',
#  '指出',
#  '以下幾點',
#  '原因',
#  '：',
#  '●',
#  '拜登',
#  '對',
#  '自己',
#  '深信不疑',
#  '拜登',
#  '儘管',
#  '年事已高',
#  '，',
#  '但',
#  '先前',
#  '還是',
#  '做出',
#  '競選',
#  '連任',
#  '決定',
#  '。',
#  '當時',
#  '官員',
#  '他',
#  '政壇',
#  '盟友',
#  '告訴',
#  '路透社',
#  '，',
#  '這',
#  '主要',
#  '因為',
#  '他',
#  '相信',
#  '自己',
#  '能',
#  '擊敗',
#  '川普',
#  '民主黨',
#  '最佳人選',
#  '。',
#  '這些',
#  '消息人士',
#  '透露',
#  '，',
#  '拜登',
#  '信不過',
#  '副手',
#  '賀錦麗',
#  '（',
#  'Kamala',
#  ' ',
#  'Harris',
#  '）',
#  '贏得',
#  '中間',
#  '選民',
#  '能力',
#  '，',
#  '尤其',
#  '在',
#  '關鍵',
#  '搖擺',
#  '州',
#  '。',
#  '此外',
#  '，',
#  '對於',
#  '眾多',
#  '等待',
#  '上場',
#  '民主黨',
#  '州長',
#  '很',
#  '可能',
#  '成為',
#  '未來',
#  '黨內',
#  '領袖',
#  '國會議員',
#  '，',
#  '拜登',
#  '也',
#  '懷疑',
#  '能力',
#  '。',
#  '●',
#  '拜登',
#  '人格特質',
#  '懷抱',
#  '堅持不懈',
#  '原則',
#  '，',
#  '向來',
#  '拜登',
#  '度過',
#  '充滿',
#  '悲痛',
#  '人生',
#  '漫長',
#  '從政',
#  '生涯',
#  '關鍵',
#  '。',
#  '他',
#  '說',
#  '，',
#  '這是',
#  '源於',
#  '父母',
#  '教誨',
#  '。',
#  '拜登',
#  '表示',
#  '，',
#  '母親',
#  '教導',
#  '他',
#  '：',
#  '「',
#  '人生',
#  '某些',
#  '時刻',
#  '遭遇',
#  '失敗',
#  '無可避免',
#  '，',
#  '但',
#  '放棄',
#  '不可',
#  '原諒',
#  '。',
#  '」',
#  '然而',
#  '，',
#  '拜登',
#  '這項',
#  '原則',
#  '令',
#  '諸多',
#  '民主黨人',
#  '擔憂',
#  '。',
#  '好萊塢',
#  '男星',
#  '喬治',
#  '克隆',
#  '尼',
#  '（',
#  'George',
#  ' ',
#  'Clooney',
#  '）',
#  '10',
#  '日',
#  '投書',
#  '「',
#  '紐約時報',
#  '」',
#  '（',
#  'The',
#  ' ',
#  'New',
#  ' ',
#  'York',
#  ' ',
#  'Times',
#  '）',
#  '呼籲',
#  '他',
#  '退選',
#  '時',
#  '也',
#  '呼應',
#  '道',
#  '：',
#  '「',
#  '歲月',
#  '對抗',
#  '，',
#  '一場',
#  '他',
#  '不',
#  '可能',
#  '打贏',
#  '戰爭',
#  '。',
#  '人能',
#  '贏得',
#  '。',
#  '」',
#  '●',
#  '拜登',
#  '最',
#  '親近',
#  '幕僚',
#  '比',
#  '他',
#  '本人',
#  '還',
#  '放不下',
#  '數十年',
#  '來',
#  '，',
#  '拜登',
#  '讓',
#  '自己',
#  '身邊',
#  '圍繞',
#  '一群',
#  '為數',
#  '不',
#  '多',
#  '資深',
#  '幕僚',
#  '作為',
#  '幹部',
#  '，',
#  '例如',
#  '政治',
#  '顧問',
#  '唐尼倫',
#  '（',
#  'MikeDonilon',
#  '）',
#  '、',
#  '現任',
#  '美國',
#  '總統',
#  '顧問',
#  '（',
#  'Counselor',
#  ' ',
#  ' ',
#  'thePresident',
#  '）',
#  '芮契提',
#  '（',
#  'Steve',
#  ' ',
#  'Ricchetti',
#  '）',
#  '現任',
#  '白宮',
#  '副',
#  '幕僚長',
#  '利德',
#  '（',
#  'Bruce',
#  ' ',
#  'Reed',
#  '）',
#  '。',
#  '這群',
#  '人',
#  '曾',
#  '指導',
#  '拜登',
#  '度過',
#  '先前',
#  '幾次',
#  '危機',
#  '，',
#  '這次',
#  '也',
#  '力勸',
#  '他選',
#  '到底',
#  '。',
#  '一名',
#  '白宮',
#  '內',
#  '仍',
#  '有',
#  '聯繫',
#  '拜登',
#  '前',
#  '幕僚',
#  '表示',
#  '：',
#  '「',
#  '我',
#  '聽聞',
#  '芮契提',
#  '、',
#  '利德',
#  '唐尼',
#  '倫比',
#  '拜登',
#  '本人',
#  '還',
#  '堅持',
#  '。',
#  '已經',
#  '（',
#  '在',
#  '白宮',
#  '）',
#  '生根',
#  '，',
#  '不想',
#  '移動',
#  '。',
#  '」',
#  '一位',
#  '白宮',
#  '官員',
#  '證實',
#  '這番',
#  '說法',
#  '，',
#  '並稱',
#  '拜登',
#  '所有',
#  '高階',
#  '幕僚',
#  '這種',
#  '心態',
#  '。',
#  '●',
#  '一些',
#  '民主黨人',
#  '害怕',
#  '賀錦麗',
#  '帶來',
#  '變化',
#  '路透社',
#  '採訪',
#  '十幾位',
#  '民主黨人',
#  '，',
#  '包括',
#  '民選',
#  '官員',
#  '活躍',
#  '支持者',
#  '，',
#  '且',
#  '當中',
#  '不少',
#  '在',
#  '兵家必爭',
#  '賓州',
#  '。',
#  '全都',
#  '對於',
#  '拜登',
#  '心智',
#  '狀態',
#  '擊敗',
#  '川普',
#  '能力',
#  '深表',
#  '擔憂',
#  '。',
#  '不過',
#  '，',
#  '對於',
#  '若',
#  '由',
#  '賀錦麗',
#  '帶頭',
#  '組成',
#  '民主黨',
#  '政府',
#  '，',
#  '同樣',
#  '卻乏',
#  '信任',
#  '。',
#  '●',
#  '國會議員',
#  '反對',
#  '聲浪',
#  '趨緩',
#  '6',
#  '月',
#  '27',
#  '日',
#  '電視辯論',
#  '會',
#  '過後',
#  '不久',
#  '，',
#  '美國國會',
#  '黑人',
#  '國會議員',
#  '連線',
#  '（',
#  'Congressional',
#  ' ',
#  'Black',
#  ' ',
#  'Caucus',
#  '）',
#  '民主黨',
#  '國會',
#  '拉丁',
#  '裔',
#  '黨團',
#  '（',
#  'Congressional',
#  ' ',
#  'Hispanic',
#  ' ',
#  'Caucus',
#  '）',
#  '領袖',
#  '發表',
#  '支持',
#  '拜登',
#  '聲明',
#  '。',
#  '這',
#  '似乎',
#  '使得',
#  '批評',
#  '聲浪',
#  '趨緩',
#  '。',
#  '截至',
#  '昨天',
#  '，',
#  '在',
#  '民主黨',
#  '掌握',
#  '213',
#  '席',
#  '聯邦',
#  '眾',
#  '議員',
#  '51',
#  '席',
#  '聯邦',
#  '參議員',
#  '當中',
#  '，',
#  '分別',
#  '僅',
#  '11',
#  '人',
#  '1',
#  '人',
#  '懇請',
#  '拜登',
#  '急流勇退',
#  '。',
#  '美國',
#  '男星',
#  '喬治',
#  '克隆',
#  '尼',
#  '最近',
#  '投書',
#  '紐時',
#  '呼籲',
#  '總統',
#  '拜登',
#  '退選',
#  '，',
#  '開',
#  '好萊塢',
#  '「',
#  '換拜',
#  '」',
#  '第一槍',
#  '。',
#  '值此',
#  '之際',
#  '，',
#  '奧斯卡',
#  '影帝',
#  '麥克',
#  '道格拉斯',
#  '也',
#  '在',
#  '受訪',
#  '時',
#  '表示',
#  '，',
#  '他',
#  '「',
#  '難以想像',
#  '」',
#  '拜登',
#  '能',
#  '做',
#  '完',
#  '第',
#  '2',
#  '任期',
#  '。',
#  '喬治',
#  '克隆',
#  '尼',
#  '（',
#  'George',
#  ' ',
#  'Clooney',
#  '）',
#  '最近',
#  '投書',
#  '「',
#  '紐約時報',
#  '」',
#  '（',
#  'New',
#  ' ',
#  'York',
#  ' ',
#  'Times',
#  '）',
#  '，',
#  '發表',
#  '長文',
#  '要求',
#  '拜登',
#  '退選',
#  '，',
#  '並且',
#  '語重心長',
#  '指出',
#  '，',
#  '拜登',
#  '11',
#  '月',
#  '總統大選',
#  '贏',
#  '不了',
#  '，',
#  '國會',
#  '參眾',
#  '兩院',
#  '也',
#  '會輸',
#  '。',
#  '英國',
#  '「',
#  '獨立報',
#  ...]

# %% [markdown]
# ### 載入繪圖相關的 library

# %%
import matplotlib
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
print(matplotlib.matplotlib_fname())
# Out:
# /opt/conda/lib/python3.11/site-packages/matplotlib/mpl-data/matplotlibrc

# %% [markdown]
# #### 清除 matplotlib 快取

# %%
print(matplotlib.get_configdir())
# Out:
# /home/jovyan/.config/matplotlib

# %%
# !ls -la /home/jovyan/.config/matplotlib
# Out:
# total 8
# drwxr-sr-x 2 jovyan users 4096 Jul 12 21:04 .
# drwxr-sr-x 3 jovyan users 4096 Jul 12 21:04 ..

# %%
print(matplotlib.get_cachedir())
# Out:
# /home/jovyan/.cache/matplotlib

# %%
# !rm -rf /home/jovyan/.cache/matplotlib

# %%
# #用來顯示中文
# plt.rcParams['font.sans-serif']=['SimHei']
# #用來顯示負號
# plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# #### 其他 FAQ 可以參考 https://matplotlib.org/3.1.1/faq/troubleshooting_faq.html

# %% [markdown]
# ### 繪製文字雲 ( wordcloud.generate )

# %%
# wordcloud.generate 參數是吃文字內容，以空白為文字區隔
seg_words = ' '.join(seg_words_list)
#seg_words

# %%
#不同字型
wordcloud = WordCloud(font_path='fonts/SimHei.ttf').generate(seg_words)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#不同字型
wordcloud = WordCloud(font_path='fonts/TaipeiSansTCBeta-Regular.ttf').generate(seg_words)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### 繪製文字雲 ( wordcloud.generate_from_frequencies )

# %%
# https://docs.python.org/zh-tw/3/library/collections.html
# 準備一個沒有經過stop word 處理的 counter
from collections import Counter
seg_counter = Counter(seg_words_list)
seg_counter
# Out:
# Counter({'，': 530,
#          '的': 323,
#          '。': 285,
#          '拜登': 186,
#          '（': 122,
#          '）': 122,
#          '「': 120,
#          '」': 120,
#          '在': 113,
#          ' ': 101,
#          '他': 96,
#          '總統': 74,
#          '與': 72,
#          '是': 65,
#          '川普': 55,
#          '、': 52,
#          '說': 51,
#          '我': 51,
#          '美國': 50,
#          '也': 49,
#          '和': 47,
#          '但': 40,
#          '對': 40,
#          '：': 35,
#          '有': 34,
#          '人': 34,
#          '日': 31,
#          '競選': 31,
#          '民主黨': 30,
#          '月': 29,
#          '前': 27,
#          '北約': 27,
#          '表示': 26,
#          '他們': 26,
#          '都': 26,
#          '自己': 25,
#          '為': 24,
#          '退選': 24,
#          '我們': 24,
#          '了': 24,
#          '報導': 24,
#          '烏克蘭': 24,
#          '記者會': 23,
#          '會': 22,
#          '巴馬': 22,
#          '時': 21,
#          '不': 21,
#          '上': 20,
#          '歐': 20,
#          '喬治': 18,
#          '克隆': 18,
#          '後': 18,
#          '認為': 18,
#          '表現': 17,
#          '沒有': 17,
#          '11': 16,
#          '連任': 16,
#          '能力': 16,
#          '年': 15,
#          '等': 15,
#          '更': 15,
#          '曾': 15,
#          '擊敗': 15,
#          '賀錦麗': 15,
#          '尼': 15,
#          '國家': 15,
#          '讓': 14,
#          '這': 14,
#          '不會': 14,
#          '要': 14,
#          '任何': 13,
#          '3': 13,
#          '就': 13,
#          '俄羅斯': 13,
#          '中國': 13,
#          '第': 12,
#          '多': 12,
#          '人士': 12,
#          '可能': 12,
#          '好萊塢': 12,
#          '已': 12,
#          '活動': 12,
#          '中': 12,
#          '/': 12,
#          '如果': 12,
#          '今天': 12,
#          '倫斯基': 12,
#          '辯論': 12,
#          '測試': 12,
#          '愛爾蘭': 11,
#          '領袖': 11,
#          '最': 11,
#          '白宮': 11,
#          '支持': 11,
#          '做': 11,
#          '或': 11,
#          '將': 11,
#          '結束': 11,
#          '澤': 11,
#          '必須': 11,
#          '台灣': 10,
#          '總統大選': 10,
#          '幕僚': 10,
#          '告訴': 10,
#          '民主黨人': 10,
#          '內': 10,
#          '一些': 10,
#          '聯邦': 10,
#          '眾': 10,
#          '議員': 10,
#          '是否': 10,
#          '她': 10,
#          '沒': 10,
#          '裴洛西': 10,
#          '月光': 10,
#          '翻譯': 9,
#          '指出': 9,
#          '及': 9,
#          '決定': 9,
#          '比': 9,
#          '顧問': 9,
#          '仍': 9,
#          '包括': 9,
#          '2': 9,
#          '共和黨': 9,
#          '團隊': 9,
#          '名': 9,
#          '對手': 9,
#          '又': 9,
#          'CNN': 9,
#          '北美': 9,
#          '消費者': 9,
#          '半導體': 9,
#          '8': 9,
#          '10': 8,
#          '歲': 8,
#          '●': 8,
#          '能': 8,
#          '擔憂': 8,
#          '投書': 8,
#          '呼籲': 8,
#          '一場': 8,
#          '還': 8,
#          '6': 8,
#          '舉行': 8,
#          '新聞': 8,
#          '問題': 8,
#          '資格': 8,
#          '進行': 8,
#          '募款': 8,
#          '之前': 8,
#          '峰會': 8,
#          '提供': 8,
#          '奧班': 8,
#          '你': 8,
#          '公開': 8,
#          '承諾': 8,
#          '持續': 8,
#          '好': 8,
#          '4': 7,
#          '擂台': 7,
#          '以': 7,
#          '文化': 7,
#          '可以': 7,
#          '；': 7,
#          '機會': 7,
#          '？': 7,
#          '主要': 7,
#          '很': 7,
#          '國會議員': 7,
#          '戰爭': 7,
#          '副': 7,
#          '一位': 7,
#          '若': 7,
#          '要求': 7,
#          '選戰': 7,
#          '知道': 7,
#          '希望': 7,
#          '這個': 7,
#          '擔心': 7,
#          '服務': 7,
#          '峰': 7,
#          '歐盟': 7,
#          '參選': 7,
#          '被': 7,
#          '記者': 7,
#          '個': 7,
#          '口誤': 7,
#          '並': 7,
#          '歐洲': 7,
#          '季': 7,
#          '成長': 7,
#          '市場': 7,
#          '晚上': 7,
#          '合作': 6,
#          '原民': 6,
#          '莎拉': 6,
#          '訪談': 6,
#          '今年': 6,
#          '透過': 6,
#          '電視辯論': 6,
#          '路透社': 6,
#          '金主': 6,
#          '盟友': 6,
#          '因為': 6,
#          '紐約時報': 6,
#          '來': 6,
#          '已經': 6,
#          '麥克': 6,
#          '道格拉斯': 6,
#          '贏': 6,
#          'NBC': 6,
#          '於': 6,
#          '一次': 6,
#          '現在': 6,
#          '黨籍': 6,
#          '事': 6,
#          '目前': 6,
#          '華府': 6,
#          '適合': 6,
#          '把': 6,
#          '再次': 6,
#          '普亭': 6,
#          '俄國': 6,
#          '蒲亭': 6,
#          '攻擊': 6,
#          '明確': 6,
#          '態度': 6,
#          '不是': 6,
#          '所得': 6,
#          'ISE': 6,
#          'Labs': 6,
#          '詩人': 5,
#          '茅群': 5,
#          '記事': 5,
#          '1': 5,
#          '卻': 5,
#          '議題': 5,
#          '81': 5,
#          '5': 5,
#          '官員': 5,
#          '先前': 5,
#          '這些': 5,
#          '消息人士': 5,
#          '對於': 5,
#          'The': 5,
#          '政治': 5,
#          '到底': 5,
#          '說法': 5,
#          '所有': 5,
#          '不過': 5,
#          '感到': 5,
#          '小時': 5,
#          '梅蘭': 5,
#          '參加': 5,
#          '稱': 5,
#          '努力': 5,
#          '正在': 5,
#          '繼續': 5,
#          '民調': 5,
#          '其他': 5,
#          '質疑': 5,
#          '.': 5,
#          '法新社': 5,
#          '以及': 5,
#          '表明': 5,
#          '加州': 5,
#          '北大西洋公約組織': 5,
#          'NATO': 5,
#          '會後': 5,
#          '7': 5,
#          '相關': 5,
#          '這樣': 5,
#          '陣營': 5,
#          '領導': 5,
#          '這場': 5,
#          '下': 5,
#          '許多': 5,
#          '領導人': 5,
#          '評估': 5,
#          'Conagra': 5,
#          '公司': 5,
#          '產品': 5,
#          '百事': 5,
#          '自體': 5,
#          'AI': 5,
#          'G42': 5,
#          '主席': 5,
#          '考慮': 5,
#          '開始': 5,
#          '廠區': 5,
#          '大學': 4,
#          '各國': 4,
#          '黃': 4,
#          '璽': 4,
#          '詩作': 4,
#          '原住民': 4,
#          '文學': 4,
#          '舉辦': 4,
#          '詩': 4,
#          '首次': 4,
#          '社群': 4,
#          '面臨': 4,
#          '各界': 4,
#          '對話': 4,
#          'Joe': 4,
#          'Biden': 4,
#          '他會': 4,
#          '當時': 4,
#          '相信': 4,
#          '贏得': 4,
#          '尤其': 4,
#          '州': 4,
#          '未來': 4,
#          'George': 4,
#          'Clooney': 4,
#          '幹部': 4,
#          '現任': 4,
#          '一名': 4,
#          '政府': 4,
#          '聲浪': 4,
#          '27': 4,
#          '發表': 4,
#          '聲明': 4,
#          '批評': 4,
#          '昨天': 4,
#          '最近': 4,
#          '不了': 4,
#          '出席': 4,
#          '需要': 4,
#          '還說': 4,
#          '看到': 4,
#          '訪問': 4,
#          '全國代表大會': 4,
#          '妮亞': 4,
#          '重要': 4,
#          '回應': 4,
#          '15': 4,
#          '最後': 4,
#          '去': 4,
#          '獲勝': 4,
#          '高': 4,
#          '過去': 4,
#          '一直': 4,
#          '私下': 4,
#          '結果': 4,
#          '跟': 4,
#          '內部': 4,
#          '其他人': 4,
#          '顯示': 4,
#          '該': 4,
#          '發言人': 4,
#          '堅稱': 4,
#          '產業': 4,
#          '地': 4,
#          '年紀': 4,
#          '真的': 4,
#          '強調': 4,
#          '匈牙利': 4,
#          '因': 4,
#          '-': 4,
#          '討論': 4,
#          '情況': 4,
#          '面對': 4,
#          '程度': 4,
#          '召開': 4,
#          '民主': 4,
#          '新': 4,
#          '美國有線電視新聞網': 4,
#          '議院': 4,
#          '表態': 4,
#          '兩週': 4,
#          '立場': 4,
#          '選舉': 4,
#          '不願': 4,
#          '75': 4,
#          '擴大': 4,
#          '每天': 4,
#          '調整': 4,
#          '確保': 4,
#          '會上': 4,
#          '正': 4,
#          '年度': 4,
#          '預期': 4,
#          '約': 4,
#          '執行長': 4,
#          '需求': 4,
#          '投資': 4,
#          '轉移': 4,
#          '安全': 4,
#          '行程': 4,
#          '一下': 4,
#          '布局': 4,
#          '墨西哥': 4,
#          '三一': 3,
#          '起': 3,
#          '以台灣': 3,
#          '華語': 3,
#          '為題': 3,
#          '雖': 3,
#          '瞭解': 3,
#          '親近': 3,
#          '接著': 3,
#          '不僅': 3,
#          '進一步': 3,
#          '及其': 3,
#          '交流': 3,
#          '做出': 3,
#          '透露': 3,
#          '副手': 3,
#          '關鍵': 3,
#          '此外': 3,
#          '州長': 3,
#          '黨內': 3,
#          '懷疑': 3,
#          '這是': 3,
#          '某些': 3,
#          'New': 3,
#          'York': 3,
#          'Times': 3,
#          '呼應': 3,
#          '一個': 3,
#          '圍繞': 3,
#          '例如': 3,
#          '聯繫': 3,
#          '這種': 3,
#          '支持者': 3,
#          '且': 3,
#          '國會': 3,
#          '參議員': 3,
#          '之際': 3,
#          '英國': 3,
#          '紐約': 3,
#          '向': 3,
#          '外界': 3,
#          '到': 3,
#          '非常': 3,
#          '有助': 3,
#          '接受': 3,
#          '前景': 3,
#          '大選': 3,
#          '一起': 3,
#          '美聯社': 3,
#          '晚間': 3,
#          '候選人': 3,
#          '可能性': 3,
#          '從': 3,
#          '會晤': 3,
#          '應該': 3,
#          '提名': 3,
#          '像是': 3,
#          '而': 3,
#          '更好': 3,
#          '如何': 3,
#          '很多': 3,
#          '來說': 3,
#          '參選人': 3,
#          '爭取': 3,
#          '超過': 3,
#          '萬美元': 3,
#          '平台': 3,
#          '點': 3,
#          '上週': 3,
#          '會面': 3,
#          '擔任': 3,
#          '寫道': 3,
#          '入侵': 3,
#          '俄': 3,
#          '政策': 3,
#          '前往': 3,
#          '時說': 3,
#          '足夠': 3,
#          '根據': 3,
#          '誤稱': 3,
#          '自家': 3,
#          '兩人': 3,
#          '出現': 3,
#          '動盪': 3,
#          '談話': 3,
#          '拒絕': 3,
#          '置評': 3,
#          '重申': 3,
#          '打算': 3,
#          '之一': 3,
#          '至少': 3,
#          '就是': 3,
#          '時間': 3,
#          '一切': 3,
#          '出來': 3,
#          'Volodymyr': 3,
#          'Zelenskyy': 3,
#          '系統': 3,
#          '烏': 3,
#          '聽取': 3,
#          '建議': 3,
#          '蕭茲': 3,
#          '品牌': 3,
#          '業績': 3,
#          '支出': 3,
#          '營收': 3,
#          '銷量': 3,
#          '下滑': 3,
#          '涵蓋': 3,
#          '減少': 3,
#          '銷售': 3,
#          '預估': 3,
#          '價格': 3,
#          '日前': 3,
#          '宣布': 3,
#          '兩名': 3,
#          '對此': 3,
#          '敏感': 3,
#          '技術': 3,
#          '麥': 3,
#          '考爾': 3,
#          '微軟': 3,
#          '交易': 3,
#          '疑慮': 3,
#          '與其': 3,
#          '憂心': 3,
#          '展現': 3,
#          '盼': 3,
#          '從頭開始': 3,
#          '準備': 3,
#          '打交道': 3,
#          '習近平': 3,
#          '然後': 3,
#          '聽到': 3,
#          '9': 3,
#          '檢查': 3,
#          '工作': 3,
#          '佛利': 3,
#          '蒙特': 3,
#          '供應鏈': 3,
#          ',': 3,
#          'Inc': 3,
#          '客戶': 3,
#          '工程': 3,
#          '現有': 3,
#          '新廠區': 3,
#          '文學館': 2,
#          '近日': 2,
#          '競賽': 2,
#          '英語': 2,
#          '泰雅族': 2,
#          '2021': 2,
#          '創作': 2,
#          '中心': 2,
#          '駐': 2,
#          'Slam': 2,
#          '哈德': 2,
#          '挑戰': 2,
#          '作品': 2,
#          '開發': 2,
#          '環境': 2,
#          '既': 2,
#          '特別': 2,
#          '參': 2,
#          '代表': 2,
#          '歷史': 2,
#          '講述': 2,
#          '慘不忍睹': 2,
#          '現年': 2,
#          '堅信': 2,
#          'Donald': 2,
#          'Trump': 2,
#          '儘管': 2,
#          '政壇': 2,
#          '最佳人選': 2,
#          'Kamala': 2,
#          'Harris': 2,
#          '成為': 2,
#          '原則': 2,
#          '度過': 2,
#          '人生': 2,
#          '時刻': 2,
#          '放棄': 2,
#          '然而': 2,
#          '這項': 2,
#          '令': 2,
#          '男星': 2,
#          '打贏': 2,
#          '本人': 2,
#          '數十年': 2,
#          '資深': 2,
#          '芮契提': 2,
#          'Steve': 2,
#          '利德': 2,
#          '這次': 2,
#          '並稱': 2,
#          '帶來': 2,
#          '採訪': 2,
#          '當中': 2,
#          '不少': 2,
#          '全都': 2,
#          '由': 2,
#          '信任': 2,
#          '反對': 2,
#          '趨緩': 2,
#          'Congressional': 2,
#          'Caucus': 2,
#          '似乎': 2,
#          '掌握': 2,
#          '213': 2,
#          '席': 2,
#          '51': 2,
#          '僅': 2,
#          '紐時': 2,
#          '換拜': 2,
#          '難以想像': 2,
#          '完': 2,
#          '獨立報': 2,
#          'Independent': 2,
#          'Michael': 2,
#          '表達': 2,
#          'BBC': 2,
#          '狀況': 2,
#          '如此': 2,
#          '得': 2,
#          '清楚': 2,
#          '首場': 2,
#          '失望': 2,
#          '各位': 2,
#          '關注': 2,
#          '…': 2,
#          '文章': 2,
#          '數': 2,
#          '觀點': 2,
#          '熟悉': 2,
#          '第一夫人': 2,
#          '缺席': 2,
#          '多場': 2,
#          '此次': 2,
#          '超級': 2,
#          '立即': 2,
#          '發表談話': 2,
#          '18': 2,
#          '競選活動': 2,
#          '投票': 2,
#          '期間': 2,
#          '私人': 2,
#          '捍衛': 2,
#          '幾位': 2,
#          '越來越': 2,
#          '位': 2,
#          '這件': 2,
#          '當晚': 2,
#          '發生': 2,
#          '據': 2,
#          '重新考慮': 2,
#          '增加': 2,
#          '負責': 2,
#          '黨工': 2,
#          '即使': 2,
#          '成員': 2,
#          '支援': 2,
#          '最有': 2,
#          '十分': 2,
#          '普遍': 2,
#          '另': 2,
#          '選上': 2,
#          '著': 2,
#          '認知': 2,
#          '缺乏': 2,
#          '難以': 2,
#          '關係密切': 2,
#          '還有': 2,
#          '誰': 2,
#          '打敗': 2,
#          '一點': 2,
#          '站': 2,
#          '最終': 2,
#          '無論是': 2,
#          'X': 2,
#          '連結': 2,
#          'https': 2,
#          ':': 2,
#          'com': 2,
#          '一天': 2,
#          '資金': 2,
#          '巨星': 2,
#          '捐款者': 2,
#          '撤資': 2,
#          '再度': 2,
#          '引發': 2,
#          '重大': 2,
#          '週前': 2,
#          '洛杉磯': 2,
#          '3000': 2,
#          '資助': 2,
#          '實力': 2,
#          '羅斯': 2,
#          '聯合': 2,
#          '創辦人': 2,
#          '迪士尼': 2,
#          '創造': 2,
#          '不論': 2,
#          '至關重要': 2,
#          '財務': 2,
#          '方面': 2,
#          '擁有': 2,
#          '強大': 2,
#          '嗎': 2,
#          '過的': 2,
#          '馬': 2,
#          '維葛利歐': 2,
#          '對決': 2,
#          '回到': 2,
#          '不足以': 2,
#          '總理': 2,
#          '轉赴': 2,
#          '佛羅里達州': 2,
#          '會見': 2,
#          'Viktor': 2,
#          'Orban': 2,
#          'Vladimir': 2,
#          'Putin': 2,
#          '對方': 2,
#          '恐': 2,
#          '身為': 2,
#          '與川普': 2,
#          '獲': 2,
#          '媒體': 2,
#          '和平': 2,
#          '！': 2,
#          '全面': 2,
#          '統計': 2,
#          '會談': 2,
#          '任務': 2,
#          '芬蘭': 2,
#          '史': 2,
#          '塔布': 2,
#          'Alexander': 2,
#          'Stubb': 2,
#          '未獲': 2,
#          '談判': 2,
#          '不能': 2,
#          '迫使': 2,
#          '材料': 2,
#          'Politico': 2,
#          '戰略': 2,
#          '即': 2,
#          '精神': 2,
#          '民主黨員': 2,
#          '隨即': 2,
#          '看法': 2,
#          '事情': 2,
#          '糟糕': 2,
#          '展示': 2,
#          '議長': 2,
#          '談過': 2,
#          '愈來愈': 2,
#          '難': 2,
#          '太': 2,
#          '專注': 2,
#          '參議院': 2,
#          '轉向': 2,
#          '12': 2,
#          '其中': 2,
#          '終結': 2,
#          '只': 2,
#          '距離': 2,
#          '覺得': 2,
#          '維持': 2,
#          '在所難免': 2,
#          '抱持': 2,
#          '往來': 2,
#          '否認': 2,
#          '自稱': 2,
#          '捐款人': 2,
#          '避免': 2,
#          '採取': 2,
#          '堅守': 2,
#          '徵詢': 2,
#          '鼓勵': 2,
#          '機構': 2,
#          '一樣': 2,
#          '多次': 2,
#          '甚至': 2,
#          '聯盟': 2,
#          '成員國': 2,
#          '集體': 2,
#          '防禦': 2,
#          '條款': 2,
#          '軍': 2,
#          '限制': 2,
#          '各': 2,
#          '德國總理': 2,
#          'Olaf': 2,
#          'Scholz': 2,
#          '改變': 2,
#          '最大': 2,
#          '歸': 2,
#          '食品': 2,
#          '百事公司': 2,
#          'Pepsi': 2,
#          '疲弱': 2,
#          '購物者': 2,
#          '壓力': 2,
#          '陷入困境': 2,
#          '最新': 2,
#          '警報': 2,
#          '生產': 2,
#          '多力': 2,
#          '滋': 2,
#          '止於': 2,
#          '因素': 2,
#          '低於': 2,
#          '分析師': 2,
#          '2%': 2,
#          '3%': 2,
#          '通': 2,
#          '膨': 2,
#          '平價': 2,
#          '零食': 2,
#          '調降': 2,
#          '成長率': 2,
#          '4%': 2,
#          '拉瓜塔': 2,
#          '低': 2,
#          '提高': 2,
#          '空間': 2,
#          '今': 2,
#          '一': 2,
#          '廣泛': 2,
#          '人工智慧': 2,
#          '共和': 2,
#          '委員會': 2,
#          '穆': 2,
#          '勒納': 2,
#          '爾': 2,
#          '蘇利文': 2,
#          '簡報': 2,
#          '下一階段': 2,
#          '涉及': 2,
#          '出口': 2,
#          '模型': 2,
#          '可': 2,
#          '數據': 2,
#          '未': 2,
#          '推動': 2,
#          '夥伴關係': 2,
#          '提到': 2,
#          '阿聯': 2,
#          'Al': 2,
#          '北京': 2,
#          '理由': 2,
#          '紛紛': 2,
#          '解圍': 2,
#          '緩頰': 2,
#          '出於': 2,
#          '直接': 2,
#          '杜達': 2,
#          '差': 2,
#          '問答': 2,
#          '能耐': 2,
#          '不佳': 2,
#          '關於': 2,
#          '名字': 2,
#          '稍早': 2,
#          '多數': 2,
#          '勝算': 2,
#          '會否': 2,
#          '退出': 2,
#          '提問': 2,
#          '結果顯示': 2,
#          '一度': 2,
#          '搞混': 2,
#          '除非': 2,
#          '確信': 2,
#          '川普會贏': 2,
#          '詳述': 2,
#          '全球': 2,
#          '如': 2,
#          '怎麼': 2,
#          '不要': 2,
#          '開放': 2,
#          '有人': 2,
#          '智慧': 2,
#          '追問': 2,
#          '說明': 2,
#          '傳出': 2,
#          '13': 2,
#          '再': 2,
#          '2000': 2,
#          '安排': 2,
#          '步調': 2,
#          '提早': 2,
#          '製造': 2,
#          '廠': 2,
#          '旗下': 2,
#          '聖荷西': 2,
#          '開設': 2,
#          '市': 2,
#          '營運': 2,
#          '先進': 2,
#          '駕駛': 2,
#          '驗證': 2,
#          '選擇': 2,
#          '分析': 2,
#          '當地': 2,
#          '億元': 2,
#          '電子': 2,
#          '封裝': 2,
#          '產能': 2,
#          '愈來愈多': 2,
#          '上川普': 2,
#          '坦言': 2,
#          '這麼': 2,
#          '上床': 2,
#          '笑': 2,
#          '意思': 2,
#          '幾乎': 2,
#          '什麼': 2,
#          '中有': 2,
#          '調查': 2,
#          '國立': 1,
#          '啟動': 1,
#          '屆': 1,
#          '廣邀': 1,
#          '好手': 1,
#          '將台灣': 1,
#          'TemuSuyan': 1,
#          '譯為': 1,
#          '投稿': 1,
#          '截止': 1,
#          '生於': 1,
#          '1990': 1,
#          '具': 1,
#          '布農族': 1,
#          '血統': 1,
#          '新生代': 1,
#          '獲台灣': 1,
#          '文學獎': 1,
#          '漢語': 1,
#          '新詩': 1,
#          '首獎': 1,
#          '2023': 1,
#          '出版': 1,
#          '詩集': 1,
#          '骨鯁': 1,
#          '集': 1,
#          'Khu': 1,
#          'Ka': 1,
#          'Qaraw': 1,
#          'Qulih': 1,
#          '都柏林': 1,
#          'Trinity': 1,
#          'College': 1,
#          'Dublin': 1,
#          'Centre': 1,
#          'for': 1,
#          'Literary': 1,
#          '&': 1,
#          'CulturalTranslation': 1,
#          '代表處': 1,
#          'Translation': 1,
#          '歷年': 1,
#          '陸續': 1,
#          '台語': 1,
#          '詩及': 1,
#          '客語': 1,
#          '詩為題': 1,
#          '改由': 1,
#          '方': 1,
#          '並以': 1,
#          '主任': 1,
#          '利': 1,
#          'James': 1,
#          'Hadley': 1,
#          '深刻': 1,
#          '呈現': 1,
#          '觸及': 1,
#          '水資源': 1,
#          '過度': 1,
#          '變遷': 1,
#          '同為': 1,
#          '島國': 1,
#          '同理': 1,
#          '體會': 1,
#          '利說': 1,
#          '高度重視': 1,
#          '多樣性': 1,
#          '文壇': 1,
#          '創舉': 1,
#          '世界': 1,
#          '豐富': 1,
#          '參賽者': 1,
#          '容易': 1,
#          '錄製': 1,
#          '專訪': 1,
#          '及黃璽': 1,
#          '朗讀': 1,
#          '影音': 1,
#          '檔供': 1,
#          '楊子': 1,
#          '葆': 1,
#          '台文館': 1,
#          '展': 1,
#          '多樣': 1,
#          ...})

# %%
# 準備一個有經過stop word 處理的 counter
from collections import Counter
seg_stop_counter = Counter(seg_stop_words_list)
#seg_stop_counter

# %%
#沒有處理stop words
wordcloud = WordCloud(font_path='fonts/TaipeiSansTCBeta-Regular.ttf').generate_from_frequencies(seg_counter)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#有處理stop words
wordcloud = WordCloud(font_path='fonts/TaipeiSansTCBeta-Regular.ttf').generate_from_frequencies(seg_stop_counter)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
